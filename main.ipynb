# %%
"""
The VertiSync Scheduling Policy from the following paper:
https://ieeexplore.ieee.org/abstract/document/10422121

Author: Milad Pooladsanj, 2024
"""

# Import PuLP modeler functions
from pulp import *
import collections
import time
path_to_gurobi = r'C:\gurobi1101\win64\bin\gurobi_cl.exe'

# %%
vertiports = ["HB", "LB", "DTLA1", "DTLA2"]
OD_pairs = ["HB_DTLA1", "HB_DTLA2", "LB_DTLA1", "LB_DTLA2",
            "DTLA2_HB", "DTLA1_LB", "HB_LB", "LB_HB"
           ]
OD_Dest = {"HB": ["DTLA2_HB", "LB_HB"],
           "LB": ["DTLA1_LB", "HB_LB"],
           "DTLA1": ["HB_DTLA1", "LB_DTLA1"],
           "DTLA2": ["HB_DTLA2", "LB_DTLA2"]
          }
OD_Origin = {"HB": ["HB_DTLA1", "HB_DTLA2", "HB_LB"],
             "LB": ["LB_DTLA1", "LB_DTLA2", "LB_HB"],
             "DTLA1": ["DTLA1_LB"],
             "DTLA2": ["DTLA2_HB"]
            }
demand = {"HB_DTLA1": 1, "HB_DTLA2": 1, "LB_DTLA1": 1, "LB_DTLA2": 1,
         "DTLA2_HB": 1, "DTLA1_LB": 0, "HB_LB": 0, "LB_HB": 0
         }
# Separation margin during takeoff and landing
tau = 5 #minutes

# Separation margin in air
tau_c = 0.5 #minutes

# k_{\tau}
k_tau = int(tau / tau_c)

# Number of aircraft
num_aircraft = 4
aircraft_list = ["a" + str(i) for i in range(num_aircraft)]

# An upper-bound on the length of the cycle
upper_cycle_time = 100 # \tau_c
time_list = ["n" + str(i) for i in range(upper_cycle_time)]

# Time it takes to traverse each O-D pair
time_to_traverse = {"HB_DTLA1": 8, "HB_DTLA2": 8, "LB_DTLA1": 8, "LB_DTLA2": 8,
                    "DTLA2_HB": 8, "DTLA1_LB": 8, "HB_LB": 6, "LB_HB": 6
                   }

# Number of slots associated with each O-D pair
num_slots = collections.Counter()
slot_list = collections.defaultdict(list)
for od in OD_pairs:
    num_slots[od] = int(time_to_traverse[od] / tau_c)
    slot_list[od] = ["s" + str(i) for i in range(num_slots[od])]

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("VertiSync Policy", LpMinimize)

# Create a list of tuples containing all slots for each aircraft/route
#time_aircraft_tuple = [(n, a) for n in range(upper_cycle_time) for a in range(num_aircraft)]
#for od in OD_pairs:
#    slots.extend((od, i, n, a) 
#                 for i in range(num_slots[od])
#                 for n in range()
#                 for a in range(num_aircraft)
#                ) 
    
# A dictionary called 'w' is created to contain the decision variables w_{i,n}^{a,p}
w = {}
for p in OD_pairs:
    temp = LpVariable.dicts("w", ([p], slot_list[p], time_list, aircraft_list), 0, None, LpInteger)
    w.update(temp) 

# A dictionary called 'wd' is created to contain the decision variables w_{d,n}^{a,p}
wd = {}
for p in OD_pairs:
    temp = LpVariable.dicts("wd", ([p], time_list, aircraft_list), 0, None, LpInteger)
    wd.update(temp) 

# A dictionary called 'wo' is created to contain the decision variables w_{o,n}^{a,p}
wo = {}
for p in OD_pairs:
    temp = LpVariable.dicts("wo", ([p], time_list, aircraft_list), 0, None, LpInteger)
    wo.update(temp) 
    
# A dictionary called 'u_van' is created to contain the decision variables u_{v, n}^{a}
u = LpVariable.dicts("u", (vertiports, time_list, aircraft_list),  cat="Binary")
# A dictionary called 'z_van' is created to contain the decision variables z_{v, n}^{a}
z = LpVariable.dicts("z", (vertiports, time_list, aircraft_list),  cat="Binary")

# %%
prob = LpProblem("VertiSync Policy", LpMinimize)
# Objective function    

prob += (
    lpSum([(wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a]) * time_to_traverse[p]
          for p in OD_pairs for n in range(1,upper_cycle_time) for a in aircraft_list]),
         "Sum_of_Travel_Times",
) 

# Constraints
# Service all trip requests (2a)
for p in OD_pairs: 
    prob += lpSum(wo[p][time_list[-1]][a] for a in aircraft_list) >= demand[p]

# w, wo, wd must be non-decreasing over time (2b)
for p in OD_pairs:
    for n in range(1, upper_cycle_time):
        for a in aircraft_list:
            prob += wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a] >= 0
            prob += wd[p][time_list[n]][a] - wd[p][time_list[n-1]][a] >= 0
            for i in slot_list[p]:
                prob += w[p][i][time_list[n]][a] - w[p][i][time_list[n-1]][a] >= 0

# Each aircraft must occupy at most one slot at any time (2c)
"""
for n in range(1, upper_cycle_time):
    for a in aircraft_list:
        prob += (
            lpSum(w[p][i][time_list[n]][a] - w[p][i][time_list[n-1]][a] for p in OD_pairs for i in slot_list[p]) + 
            lpSum(wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a] for p in OD_pairs) + 
            lpSum(wd[p][time_list[n]][a] - wd[p][time_list[n-1]][a] for p in OD_pairs) <= 1
        )
"""
# Each flying aircraft moves to the next slot at the next time step (2d)
for p in OD_pairs:
    for n in range(1, upper_cycle_time):
        for a in aircraft_list:
            prob += w[p][slot_list[p][-1]][time_list[n-1]][a] == wd[p][time_list[n]][a]
            prob += wo[p][time_list[n-1]][a] == w[p][slot_list[p][0]][time_list[n]][a]
            for i in range(num_slots[p] - 1):
                prob += w[p][slot_list[p][i]][time_list[n-1]][a] == w[p][slot_list[p][i+1]][time_list[n]][a]

# At most one aircraft must occupy overlapping slots (2e)
p = "HB_DTLA1"
q = "HB_DTLA2"
for i in range(num_slots[p]):
    for n in range(1, upper_cycle_time):
        prob += (
            lpSum(w[p][slot_list[p][i]][time_list[n]][a] - w[p][slot_list[p][i]][time_list[n-1]][a] +
                  w[q][slot_list[q][i]][time_list[n]][a] - w[q][slot_list[q][i]][time_list[n-1]][a]
                  for a in aircraft_list) <= 1
        )
r = "LB_DTLA1"
s = "LB_DTLA2"
for i in range(num_slots[r]):
    for n in range(1, upper_cycle_time):
        prob += (
            lpSum(w[r][slot_list[r][i]][time_list[n]][a] - w[r][slot_list[r][i]][time_list[n-1]][a] +
                  w[s][slot_list[s][i]][time_list[n]][a] - w[s][slot_list[s][i]][time_list[n-1]][a]
                  for a in aircraft_list) <= 1
        )
for i in range(6, 12):
    for n in range(1, upper_cycle_time):
        prob += (
            lpSum(w[p][slot_list[p][i]][time_list[n]][a] - w[p][slot_list[p][i]][time_list[n-1]][a] +
                  w[q][slot_list[q][i]][time_list[n]][a] - w[q][slot_list[q][i]][time_list[n-1]][a] +
                  w[r][slot_list[r][i]][time_list[n]][a] - w[r][slot_list[r][i]][time_list[n-1]][a] +
                  w[s][slot_list[s][i]][time_list[n]][a] - w[s][slot_list[s][i]][time_list[n-1]][a]
                  for a in aircraft_list) <= 1
        )

# Takeoff separation must be satisfiesd at every vertiport (2f)
for n in range(k_tau, upper_cycle_time):
    prob += (
        lpSum(wo[p][time_list[n]][a] - wo[p][time_list[n-k_tau]][a] +
              wo[q][time_list[n]][a] - wo[q][time_list[n-k_tau]][a] +
              wo["HB_LB"][time_list[n]][a] - wo["HB_LB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo[r][time_list[n]][a] - wo[r][time_list[n-k_tau]][a] +
              wo[s][time_list[n]][a] - wo[s][time_list[n-k_tau]][a] +
              wo["LB_HB"][time_list[n]][a] - wo["LB_HB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo["DTLA2_HB"][time_list[n]][a] - wo["DTLA2_HB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo["DTLA1_LB"][time_list[n]][a] - wo["DTLA1_LB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )

# Takeoffs must occur only after an aircraft is available at a vertiport (2g)
# After takeoff, aircraft availability at a veriport is set to zero (2h)
# After landing, aircraft availability at a veriport is set to one (2j)
for v in vertiports:
    for n in range(k_tau, upper_cycle_time):
        for a in aircraft_list:
            prob += (
                lpSum(wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a]
                     for p in OD_Origin[v]) <= 
                     u[v][time_list[n-k_tau]][a]
            )
            
            prob += (
                u[v][time_list[n-k_tau+1]][a] ==
                u[v][time_list[n-k_tau]][a] -
                lpSum(wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a]
                     for p in OD_Origin[v]) +
                lpSum(wd[p][time_list[n-k_tau+1]][a] - wd[p][time_list[n-k_tau]][a]
                     for p in OD_Dest[v]
                )
            )

# Landing separation must be satisfiesd at every vertiport (2i)
p = "HB_DTLA1"
q = "HB_DTLA2"
r = "LB_DTLA1"
s = "LB_DTLA2"
for n in range(k_tau, upper_cycle_time):
    prob += (
        lpSum(wo[p][time_list[n]][a] - wo[p][time_list[n-1]][a] +
              wo[q][time_list[n]][a] - wo[q][time_list[n-1]][a] +
              wo["HB_LB"][time_list[n]][a] - wo["HB_LB"][time_list[n-1]][a] +
              wd["DTLA2_HB"][time_list[n-1]][a] - wd["DTLA2_HB"][time_list[n-k_tau]][a] +
              wd["LB_HB"][time_list[n-1]][a] - wd["LB_HB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo[r][time_list[n]][a] - wo[r][time_list[n-1]][a] +
              wo[s][time_list[n]][a] - wo[s][time_list[n-1]][a] +
              wo["LB_HB"][time_list[n]][a] - wo["LB_HB"][time_list[n-1]][a] +
              wd["DTLA1_LB"][time_list[n-1]][a] - wd["DTLA1_LB"][time_list[n-k_tau]][a] +
              wd["HB_LB"][time_list[n-1]][a] - wd["HB_LB"][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo["DTLA2_HB"][time_list[n]][a] - wo["DTLA2_HB"][time_list[n-1]][a] +
              wd[q][time_list[n-1]][a] - wd[q][time_list[n-k_tau]][a] +
              wd[s][time_list[n-1]][a] - wd[s][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )
    prob += (
        lpSum(wo["DTLA1_LB"][time_list[n]][a] - wo["DTLA1_LB"][time_list[n-1]][a] +
              wd[p][time_list[n-1]][a] - wd[p][time_list[n-k_tau]][a] +
              wd[r][time_list[n-1]][a] - wd[r][time_list[n-k_tau]][a]
              for a in aircraft_list) <= 1
    )

# Initial conditions
# w, wo, wd are set to zero initially
for p in OD_pairs:
    for a in aircraft_list:
        for n in range(k_tau):
            prob += wo[p][time_list[n]][a] == 0
            prob += wd[p][time_list[n]][a] == 0
            for i in slot_list[p]:
                prob += w[p][i][time_list[n]][a] == 0

for i in range(num_aircraft):
    if i % 2 == 0:
        prob += u["HB"][time_list[0]][aircraft_list[i]] == 1
        prob += u["LB"][time_list[0]][aircraft_list[i]] == 0
    else:
        prob += u["HB"][time_list[0]][aircraft_list[i]] == 0
        prob += u["LB"][time_list[0]][aircraft_list[i]] == 1

for v in vertiports[2:]:
    for a in aircraft_list:
        prob += u[v][time_list[0]][a] == 0

# %%
start_time = time.time()

# Gurobi is chosen as the solver
solver = GUROBI_CMD(path=path_to_gurobi)

# The problem data is written to an .lp file
prob.writeLP("VertiSync.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve(solver)

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])
print(prob.objective.value())

end_time = time.time()
duration = end_time - start_time
print(f"Time taken: {duration} seconds")

for v in prob.variables():
    if v.varValue > 0:
        print(v.name, "=", v.varValue)
# Out:
# Status: Optimal
# 40.0
# Time taken: 4.468522310256958 seconds
# u_DTLA1_n36_a0 = 1.0
# u_DTLA1_n37_a0 = 1.0
# u_DTLA1_n38_a0 = 1.0
# u_DTLA1_n39_a0 = 1.0
# u_DTLA1_n40_a0 = 1.0
# u_DTLA1_n41_a0 = 1.0
# u_DTLA1_n42_a0 = 1.0
# u_DTLA1_n43_a0 = 1.0
# u_DTLA1_n44_a0 = 1.0
# u_DTLA1_n45_a0 = 1.0
# u_DTLA1_n46_a0 = 1.0
# u_DTLA1_n47_a0 = 1.0
# u_DTLA1_n48_a0 = 1.0
# u_DTLA1_n49_a0 = 1.0
# u_DTLA1_n50_a0 = 1.0
# u_DTLA1_n51_a0 = 1.0
# u_DTLA1_n52_a0 = 1.0
# u_DTLA1_n53_a0 = 1.0
# u_DTLA1_n54_a0 = 1.0
# u_DTLA1_n55_a0 = 1.0
# u_DTLA1_n56_a0 = 1.0
# u_DTLA1_n57_a0 = 1.0
# u_DTLA1_n58_a0 = 1.0
# u_DTLA1_n59_a0 = 1.0
# u_DTLA1_n60_a0 = 1.0
# u_DTLA1_n61_a0 = 1.0
# u_DTLA1_n62_a0 = 1.0
# u_DTLA1_n63_a0 = 1.0
# u_DTLA1_n64_a0 = 1.0
# u_DTLA1_n65_a0 = 1.0
# u_DTLA1_n66_a0 = 1.0
# u_DTLA1_n67_a0 = 1.0
# u_DTLA1_n68_a0 = 1.0
# u_DTLA1_n69_a0 = 1.0
# u_DTLA1_n70_a0 = 1.0
# u_DTLA1_n71_a0 = 1.0
# u_DTLA1_n72_a0 = 1.0
# u_DTLA1_n73_a0 = 1.0
# u_DTLA1_n74_a0 = 1.0
# u_DTLA1_n75_a0 = 1.0
# u_DTLA1_n76_a0 = 1.0
# u_DTLA1_n77_a0 = 1.0
# u_DTLA1_n78_a0 = 1.0
# u_DTLA1_n79_a0 = 1.0
# u_DTLA1_n80_a0 = 1.0
# u_DTLA1_n81_a0 = 1.0
# u_DTLA1_n82_a0 = 1.0
# u_DTLA1_n83_a0 = 1.0
# u_DTLA1_n84_a0 = 1.0
# u_DTLA1_n85_a0 = 1.0
# u_DTLA1_n86_a0 = 1.0
# u_DTLA1_n87_a0 = 1.0
# u_DTLA1_n88_a0 = 1.0
# u_DTLA1_n89_a0 = 1.0
# u_DTLA1_n90_a0 = 1.0
# u_DTLA2_n27_a3 = 1.0
# u_DTLA2_n28_a3 = 1.0
# u_DTLA2_n29_a3 = 1.0
# u_DTLA2_n30_a3 = 1.0
# u_DTLA2_n31_a3 = 1.0
# u_DTLA2_n32_a3 = 1.0
# u_DTLA2_n33_a3 = 1.0
# u_DTLA2_n34_a3 = 1.0
# u_DTLA2_n35_a3 = 1.0
# u_DTLA2_n36_a3 = 1.0
# u_DTLA2_n37_a3 = 1.0
# u_DTLA2_n38_a3 = 1.0
# u_DTLA2_n39_a3 = 1.0
# u_DTLA2_n40_a3 = 1.0
# u_DTLA2_n41_a3 = 1.0
# u_DTLA2_n42_a3 = 1.0
# u_DTLA2_n43_a3 = 1.0
# u_DTLA2_n44_a3 = 1.0
# u_DTLA2_n45_a3 = 1.0
# u_DTLA2_n46_a3 = 1.0
# u_DTLA2_n47_a3 = 1.0
# u_DTLA2_n48_a3 = 1.0
# u_DTLA2_n49_a3 = 1.0
# u_DTLA2_n50_a3 = 1.0
# u_DTLA2_n51_a3 = 1.0
# u_DTLA2_n52_a3 = 1.0
# u_DTLA2_n53_a3 = 1.0
# u_DTLA2_n54_a3 = 1.0
# u_DTLA2_n55_a3 = 1.0
# u_DTLA2_n56_a3 = 1.0
# u_DTLA2_n57_a3 = 1.0
# u_DTLA2_n58_a3 = 1.0
# u_DTLA2_n59_a3 = 1.0
# u_DTLA2_n60_a3 = 1.0
# u_DTLA2_n61_a3 = 1.0
# u_DTLA2_n62_a3 = 1.0
# u_DTLA2_n63_a3 = 1.0
# u_DTLA2_n64_a3 = 1.0
# u_DTLA2_n65_a3 = 1.0
# u_DTLA2_n66_a3 = 1.0
# u_DTLA2_n67_a3 = 1.0
# u_DTLA2_n68_a3 = 1.0
# u_DTLA2_n69_a3 = 1.0
# u_DTLA2_n70_a3 = 1.0
# u_DTLA2_n71_a3 = 1.0
# u_DTLA2_n72_a3 = 1.0
# u_DTLA2_n73_a3 = 1.0
# u_DTLA2_n74_a3 = 1.0
# u_DTLA2_n75_a3 = 1.0
# u_DTLA2_n76_a3 = 1.0
# u_DTLA2_n77_a3 = 1.0
# u_DTLA2_n78_a3 = 1.0
# u_DTLA2_n79_a3 = 1.0
# u_DTLA2_n80_a3 = 1.0
# u_DTLA2_n81_a3 = 1.0
# u_DTLA2_n82_a3 = 1.0
# u_DTLA2_n83_a3 = 1.0
# u_DTLA2_n84_a3 = 1.0
# u_DTLA2_n85_a3 = 1.0
# u_DTLA2_n86_a3 = 1.0
# u_DTLA2_n87_a3 = 1.0
# u_DTLA2_n88_a3 = 1.0
# u_DTLA2_n89_a3 = 1.0
# u_HB_n0_a0 = 1.0
# u_HB_n0_a2 = 1.0
# u_HB_n10_a2 = 1.0
# u_HB_n11_a2 = 1.0
# u_HB_n12_a2 = 1.0
# u_HB_n13_a2 = 1.0
# u_HB_n14_a2 = 1.0
# u_HB_n15_a2 = 1.0
# u_HB_n16_a2 = 1.0
# u_HB_n17_a2 = 1.0
# u_HB_n18_a2 = 1.0
# u_HB_n19_a2 = 1.0
# u_HB_n1_a0 = 1.0
# u_HB_n1_a2 = 1.0
# u_HB_n20_a2 = 1.0
# u_HB_n21_a2 = 1.0
# u_HB_n22_a2 = 1.0
# u_HB_n23_a2 = 1.0
# u_HB_n24_a2 = 1.0
# u_HB_n25_a2 = 1.0
# u_HB_n26_a2 = 1.0
# u_HB_n27_a2 = 1.0
# u_HB_n28_a2 = 1.0
# u_HB_n29_a2 = 1.0
# u_HB_n2_a0 = 1.0
# u_HB_n2_a2 = 1.0
# u_HB_n30_a2 = 1.0
# u_HB_n31_a2 = 1.0
# u_HB_n32_a2 = 1.0
# u_HB_n33_a2 = 1.0
# u_HB_n34_a2 = 1.0
# u_HB_n35_a2 = 1.0
# u_HB_n36_a2 = 1.0
# u_HB_n37_a2 = 1.0
# u_HB_n38_a2 = 1.0
# u_HB_n39_a2 = 1.0
# u_HB_n3_a0 = 1.0
# u_HB_n3_a2 = 1.0
# u_HB_n40_a2 = 1.0
# u_HB_n41_a2 = 1.0
# u_HB_n42_a2 = 1.0
# u_HB_n43_a2 = 1.0
# u_HB_n44_a2 = 1.0
# u_HB_n45_a2 = 1.0
# u_HB_n46_a2 = 1.0
# u_HB_n47_a2 = 1.0
# u_HB_n48_a2 = 1.0
# u_HB_n49_a2 = 1.0
# u_HB_n4_a0 = 1.0
# u_HB_n4_a2 = 1.0
# u_HB_n50_a2 = 1.0
# u_HB_n51_a2 = 1.0
# u_HB_n52_a2 = 1.0
# u_HB_n53_a2 = 1.0
# u_HB_n54_a2 = 1.0
# u_HB_n55_a2 = 1.0
# u_HB_n56_a2 = 1.0
# u_HB_n57_a2 = 1.0
# u_HB_n58_a2 = 1.0
# u_HB_n59_a2 = 1.0
# u_HB_n5_a0 = 1.0
# u_HB_n5_a2 = 1.0
# u_HB_n60_a2 = 1.0
# u_HB_n61_a2 = 1.0
# u_HB_n62_a2 = 1.0
# u_HB_n63_a2 = 1.0
# u_HB_n64_a2 = 1.0
# u_HB_n65_a2 = 1.0
# u_HB_n66_a2 = 1.0
# u_HB_n67_a2 = 1.0
# u_HB_n68_a2 = 1.0
# u_HB_n69_a2 = 1.0
# u_HB_n6_a0 = 1.0
# u_HB_n6_a2 = 1.0
# u_HB_n70_a2 = 1.0
# u_HB_n71_a2 = 1.0
# u_HB_n72_a2 = 1.0
# u_HB_n73_a2 = 1.0
# u_HB_n74_a2 = 1.0
# u_HB_n75_a2 = 1.0
# u_HB_n76_a2 = 1.0
# u_HB_n77_a2 = 1.0
# u_HB_n78_a2 = 1.0
# u_HB_n79_a2 = 1.0
# u_HB_n7_a0 = 1.0
# u_HB_n7_a2 = 1.0
# u_HB_n80_a2 = 1.0
# u_HB_n81_a2 = 1.0
# u_HB_n82_a2 = 1.0
# u_HB_n83_a2 = 1.0
# u_HB_n84_a2 = 1.0
# u_HB_n85_a2 = 1.0
# u_HB_n86_a2 = 1.0
# u_HB_n87_a2 = 1.0
# u_HB_n88_a2 = 1.0
# u_HB_n89_a2 = 1.0
# u_HB_n8_a0 = 1.0
# u_HB_n8_a2 = 1.0
# u_HB_n9_a0 = 1.0
# u_HB_n9_a2 = 1.0
# u_LB_n0_a1 = 1.0
# u_LB_n0_a3 = 1.0
# u_LB_n10_a1 = 1.0
# u_LB_n11_a1 = 1.0
# u_LB_n12_a1 = 1.0
# u_LB_n13_a1 = 1.0
# u_LB_n14_a1 = 1.0
# u_LB_n15_a1 = 1.0
# u_LB_n16_a1 = 1.0
# u_LB_n17_a1 = 1.0
# u_LB_n18_a1 = 1.0
# u_LB_n19_a1 = 1.0
# u_LB_n1_a1 = 1.0
# u_LB_n20_a1 = 1.0
# u_LB_n21_a1 = 1.0
# u_LB_n22_a1 = 1.0
# u_LB_n23_a1 = 1.0
# u_LB_n24_a1 = 1.0
# u_LB_n25_a1 = 1.0
# u_LB_n26_a1 = 1.0
# u_LB_n27_a1 = 1.0
# u_LB_n28_a1 = 1.0
# u_LB_n29_a1 = 1.0
# u_LB_n2_a1 = 1.0
# u_LB_n30_a1 = 1.0
# u_LB_n31_a1 = 1.0
# u_LB_n32_a1 = 1.0
# u_LB_n33_a1 = 1.0
# u_LB_n34_a1 = 1.0
# u_LB_n35_a1 = 1.0
# u_LB_n36_a1 = 1.0
# u_LB_n37_a1 = 1.0
# u_LB_n38_a1 = 1.0
# u_LB_n39_a1 = 1.0
# u_LB_n3_a1 = 1.0
# u_LB_n40_a1 = 1.0
# u_LB_n41_a1 = 1.0
# u_LB_n42_a1 = 1.0
# u_LB_n43_a1 = 1.0
# u_LB_n44_a1 = 1.0
# u_LB_n45_a1 = 1.0
# u_LB_n46_a1 = 1.0
# u_LB_n47_a1 = 1.0
# u_LB_n48_a1 = 1.0
# u_LB_n49_a1 = 1.0
# u_LB_n4_a1 = 1.0
# u_LB_n50_a1 = 1.0
# u_LB_n51_a1 = 1.0
# u_LB_n52_a1 = 1.0
# u_LB_n53_a1 = 1.0
# u_LB_n54_a1 = 1.0
# u_LB_n55_a1 = 1.0
# u_LB_n56_a1 = 1.0
# u_LB_n57_a1 = 1.0
# u_LB_n58_a1 = 1.0
# u_LB_n59_a1 = 1.0
# u_LB_n5_a1 = 1.0
# u_LB_n60_a1 = 1.0
# u_LB_n61_a1 = 1.0
# u_LB_n62_a1 = 1.0
# u_LB_n63_a1 = 1.0
# u_LB_n64_a1 = 1.0
# u_LB_n65_a1 = 1.0
# u_LB_n66_a1 = 1.0
# u_LB_n67_a1 = 1.0
# u_LB_n68_a1 = 1.0
# u_LB_n69_a1 = 1.0
# u_LB_n6_a1 = 1.0
# u_LB_n70_a1 = 1.0
# u_LB_n71_a1 = 1.0
# u_LB_n72_a1 = 1.0
# u_LB_n73_a1 = 1.0
# u_LB_n74_a1 = 1.0
# u_LB_n75_a1 = 1.0
# u_LB_n76_a1 = 1.0
# u_LB_n77_a1 = 1.0
# u_LB_n78_a1 = 1.0
# u_LB_n79_a1 = 1.0
# u_LB_n7_a1 = 1.0
# u_LB_n80_a1 = 1.0
# u_LB_n81_a1 = 1.0
# u_LB_n82_a1 = 1.0
# u_LB_n83_a1 = 1.0
# u_LB_n84_a1 = 1.0
# u_LB_n85_a1 = 1.0
# u_LB_n86_a1 = 1.0
# u_LB_n87_a1 = 1.0
# u_LB_n88_a1 = 1.0
# u_LB_n89_a1 = 1.0
# u_LB_n8_a1 = 1.0
# u_LB_n9_a1 = 1.0
# w_HB_DTLA1_s0_n20_a0 = 1.0
# w_HB_DTLA1_s0_n21_a0 = 1.0
# w_HB_DTLA1_s0_n22_a0 = 1.0
# w_HB_DTLA1_s0_n23_a0 = 1.0
# w_HB_DTLA1_s0_n24_a0 = 1.0
# w_HB_DTLA1_s0_n25_a0 = 1.0
# w_HB_DTLA1_s0_n26_a0 = 1.0
# w_HB_DTLA1_s0_n27_a0 = 1.0
# w_HB_DTLA1_s0_n28_a0 = 1.0
# w_HB_DTLA1_s0_n29_a0 = 1.0
# w_HB_DTLA1_s0_n30_a0 = 1.0
# w_HB_DTLA1_s0_n31_a0 = 1.0
# w_HB_DTLA1_s0_n32_a0 = 1.0
# w_HB_DTLA1_s0_n33_a0 = 1.0
# w_HB_DTLA1_s0_n34_a0 = 1.0
# w_HB_DTLA1_s0_n35_a0 = 1.0
# w_HB_DTLA1_s0_n36_a0 = 1.0
# w_HB_DTLA1_s0_n37_a0 = 1.0
# w_HB_DTLA1_s0_n38_a0 = 1.0
# w_HB_DTLA1_s0_n39_a0 = 1.0
# w_HB_DTLA1_s0_n40_a0 = 1.0
# w_HB_DTLA1_s0_n41_a0 = 1.0
# w_HB_DTLA1_s0_n42_a0 = 1.0
# w_HB_DTLA1_s0_n43_a0 = 1.0
# w_HB_DTLA1_s0_n44_a0 = 1.0
# w_HB_DTLA1_s0_n45_a0 = 1.0
# w_HB_DTLA1_s0_n46_a0 = 1.0
# w_HB_DTLA1_s0_n47_a0 = 1.0
# w_HB_DTLA1_s0_n48_a0 = 1.0
# w_HB_DTLA1_s0_n49_a0 = 1.0
# w_HB_DTLA1_s0_n50_a0 = 1.0
# w_HB_DTLA1_s0_n51_a0 = 1.0
# w_HB_DTLA1_s0_n52_a0 = 1.0
# w_HB_DTLA1_s0_n53_a0 = 1.0
# w_HB_DTLA1_s0_n54_a0 = 1.0
# w_HB_DTLA1_s0_n55_a0 = 1.0
# w_HB_DTLA1_s0_n56_a0 = 1.0
# w_HB_DTLA1_s0_n57_a0 = 1.0
# w_HB_DTLA1_s0_n58_a0 = 1.0
# w_HB_DTLA1_s0_n59_a0 = 1.0
# w_HB_DTLA1_s0_n60_a0 = 1.0
# w_HB_DTLA1_s0_n61_a0 = 1.0
# w_HB_DTLA1_s0_n62_a0 = 1.0
# w_HB_DTLA1_s0_n63_a0 = 1.0
# w_HB_DTLA1_s0_n64_a0 = 1.0
# w_HB_DTLA1_s0_n65_a0 = 1.0
# w_HB_DTLA1_s0_n66_a0 = 1.0
# w_HB_DTLA1_s0_n67_a0 = 1.0
# w_HB_DTLA1_s0_n68_a0 = 1.0
# w_HB_DTLA1_s0_n69_a0 = 1.0
# w_HB_DTLA1_s0_n70_a0 = 1.0
# w_HB_DTLA1_s0_n71_a0 = 1.0
# w_HB_DTLA1_s0_n72_a0 = 1.0
# w_HB_DTLA1_s0_n73_a0 = 1.0
# w_HB_DTLA1_s0_n74_a0 = 1.0
# w_HB_DTLA1_s0_n75_a0 = 1.0
# w_HB_DTLA1_s0_n76_a0 = 1.0
# w_HB_DTLA1_s0_n77_a0 = 1.0
# w_HB_DTLA1_s0_n78_a0 = 1.0
# w_HB_DTLA1_s0_n79_a0 = 1.0
# w_HB_DTLA1_s0_n80_a0 = 1.0
# w_HB_DTLA1_s0_n81_a0 = 1.0
# w_HB_DTLA1_s0_n82_a0 = 1.0
# w_HB_DTLA1_s0_n83_a0 = 1.0
# w_HB_DTLA1_s0_n84_a0 = 1.0
# w_HB_DTLA1_s0_n85_a0 = 1.0
# w_HB_DTLA1_s0_n86_a0 = 1.0
# w_HB_DTLA1_s0_n87_a0 = 1.0
# w_HB_DTLA1_s0_n88_a0 = 1.0
# w_HB_DTLA1_s0_n89_a0 = 1.0
# w_HB_DTLA1_s0_n90_a0 = 1.0
# w_HB_DTLA1_s0_n91_a0 = 1.0
# w_HB_DTLA1_s0_n92_a0 = 1.0
# w_HB_DTLA1_s0_n93_a0 = 1.0
# w_HB_DTLA1_s0_n94_a0 = 1.0
# w_HB_DTLA1_s0_n95_a0 = 1.0
# w_HB_DTLA1_s0_n96_a0 = 1.0
# w_HB_DTLA1_s0_n97_a0 = 1.0
# w_HB_DTLA1_s0_n98_a0 = 1.0
# w_HB_DTLA1_s0_n99_a0 = 1.0
# w_HB_DTLA1_s10_n30_a0 = 1.0
# w_HB_DTLA1_s10_n31_a0 = 1.0
# w_HB_DTLA1_s10_n32_a0 = 1.0
# w_HB_DTLA1_s10_n33_a0 = 1.0
# w_HB_DTLA1_s10_n34_a0 = 1.0
# w_HB_DTLA1_s10_n35_a0 = 1.0
# w_HB_DTLA1_s10_n36_a0 = 1.0
# w_HB_DTLA1_s10_n37_a0 = 1.0
# w_HB_DTLA1_s10_n38_a0 = 1.0
# w_HB_DTLA1_s10_n39_a0 = 1.0
# w_HB_DTLA1_s10_n40_a0 = 1.0
# w_HB_DTLA1_s10_n41_a0 = 1.0
# w_HB_DTLA1_s10_n42_a0 = 1.0
# w_HB_DTLA1_s10_n43_a0 = 1.0
# w_HB_DTLA1_s10_n44_a0 = 1.0
# w_HB_DTLA1_s10_n45_a0 = 1.0
# w_HB_DTLA1_s10_n46_a0 = 1.0
# w_HB_DTLA1_s10_n47_a0 = 1.0
# w_HB_DTLA1_s10_n48_a0 = 1.0
# w_HB_DTLA1_s10_n49_a0 = 1.0
# w_HB_DTLA1_s10_n50_a0 = 1.0
# w_HB_DTLA1_s10_n51_a0 = 1.0
# w_HB_DTLA1_s10_n52_a0 = 1.0
# w_HB_DTLA1_s10_n53_a0 = 1.0
# w_HB_DTLA1_s10_n54_a0 = 1.0
# w_HB_DTLA1_s10_n55_a0 = 1.0
# w_HB_DTLA1_s10_n56_a0 = 1.0
# w_HB_DTLA1_s10_n57_a0 = 1.0
# w_HB_DTLA1_s10_n58_a0 = 1.0
# w_HB_DTLA1_s10_n59_a0 = 1.0
# w_HB_DTLA1_s10_n60_a0 = 1.0
# w_HB_DTLA1_s10_n61_a0 = 1.0
# w_HB_DTLA1_s10_n62_a0 = 1.0
# w_HB_DTLA1_s10_n63_a0 = 1.0
# w_HB_DTLA1_s10_n64_a0 = 1.0
# w_HB_DTLA1_s10_n65_a0 = 1.0
# w_HB_DTLA1_s10_n66_a0 = 1.0
# w_HB_DTLA1_s10_n67_a0 = 1.0
# w_HB_DTLA1_s10_n68_a0 = 1.0
# w_HB_DTLA1_s10_n69_a0 = 1.0
# w_HB_DTLA1_s10_n70_a0 = 1.0
# w_HB_DTLA1_s10_n71_a0 = 1.0
# w_HB_DTLA1_s10_n72_a0 = 1.0
# w_HB_DTLA1_s10_n73_a0 = 1.0
# w_HB_DTLA1_s10_n74_a0 = 1.0
# w_HB_DTLA1_s10_n75_a0 = 1.0
# w_HB_DTLA1_s10_n76_a0 = 1.0
# w_HB_DTLA1_s10_n77_a0 = 1.0
# w_HB_DTLA1_s10_n78_a0 = 1.0
# w_HB_DTLA1_s10_n79_a0 = 1.0
# w_HB_DTLA1_s10_n80_a0 = 1.0
# w_HB_DTLA1_s10_n81_a0 = 1.0
# w_HB_DTLA1_s10_n82_a0 = 1.0
# w_HB_DTLA1_s10_n83_a0 = 1.0
# w_HB_DTLA1_s10_n84_a0 = 1.0
# w_HB_DTLA1_s10_n85_a0 = 1.0
# w_HB_DTLA1_s10_n86_a0 = 1.0
# w_HB_DTLA1_s10_n87_a0 = 1.0
# w_HB_DTLA1_s10_n88_a0 = 1.0
# w_HB_DTLA1_s10_n89_a0 = 1.0
# w_HB_DTLA1_s10_n90_a0 = 1.0
# w_HB_DTLA1_s10_n91_a0 = 1.0
# w_HB_DTLA1_s10_n92_a0 = 1.0
# w_HB_DTLA1_s10_n93_a0 = 1.0
# w_HB_DTLA1_s10_n94_a0 = 1.0
# w_HB_DTLA1_s10_n95_a0 = 1.0
# w_HB_DTLA1_s10_n96_a0 = 1.0
# w_HB_DTLA1_s10_n97_a0 = 1.0
# w_HB_DTLA1_s10_n98_a0 = 1.0
# w_HB_DTLA1_s10_n99_a0 = 1.0
# w_HB_DTLA1_s11_n31_a0 = 1.0
# w_HB_DTLA1_s11_n32_a0 = 1.0
# w_HB_DTLA1_s11_n33_a0 = 1.0
# w_HB_DTLA1_s11_n34_a0 = 1.0
# w_HB_DTLA1_s11_n35_a0 = 1.0
# w_HB_DTLA1_s11_n36_a0 = 1.0
# w_HB_DTLA1_s11_n37_a0 = 1.0
# w_HB_DTLA1_s11_n38_a0 = 1.0
# w_HB_DTLA1_s11_n39_a0 = 1.0
# w_HB_DTLA1_s11_n40_a0 = 1.0
# w_HB_DTLA1_s11_n41_a0 = 1.0
# w_HB_DTLA1_s11_n42_a0 = 1.0
# w_HB_DTLA1_s11_n43_a0 = 1.0
# w_HB_DTLA1_s11_n44_a0 = 1.0
# w_HB_DTLA1_s11_n45_a0 = 1.0
# w_HB_DTLA1_s11_n46_a0 = 1.0
# w_HB_DTLA1_s11_n47_a0 = 1.0
# w_HB_DTLA1_s11_n48_a0 = 1.0
# w_HB_DTLA1_s11_n49_a0 = 1.0
# w_HB_DTLA1_s11_n50_a0 = 1.0
# w_HB_DTLA1_s11_n51_a0 = 1.0
# w_HB_DTLA1_s11_n52_a0 = 1.0
# w_HB_DTLA1_s11_n53_a0 = 1.0
# w_HB_DTLA1_s11_n54_a0 = 1.0
# w_HB_DTLA1_s11_n55_a0 = 1.0
# w_HB_DTLA1_s11_n56_a0 = 1.0
# w_HB_DTLA1_s11_n57_a0 = 1.0
# w_HB_DTLA1_s11_n58_a0 = 1.0
# w_HB_DTLA1_s11_n59_a0 = 1.0
# w_HB_DTLA1_s11_n60_a0 = 1.0
# w_HB_DTLA1_s11_n61_a0 = 1.0
# w_HB_DTLA1_s11_n62_a0 = 1.0
# w_HB_DTLA1_s11_n63_a0 = 1.0
# w_HB_DTLA1_s11_n64_a0 = 1.0
# w_HB_DTLA1_s11_n65_a0 = 1.0
# w_HB_DTLA1_s11_n66_a0 = 1.0
# w_HB_DTLA1_s11_n67_a0 = 1.0
# w_HB_DTLA1_s11_n68_a0 = 1.0
# w_HB_DTLA1_s11_n69_a0 = 1.0
# w_HB_DTLA1_s11_n70_a0 = 1.0
# w_HB_DTLA1_s11_n71_a0 = 1.0
# w_HB_DTLA1_s11_n72_a0 = 1.0
# w_HB_DTLA1_s11_n73_a0 = 1.0
# w_HB_DTLA1_s11_n74_a0 = 1.0
# w_HB_DTLA1_s11_n75_a0 = 1.0
# w_HB_DTLA1_s11_n76_a0 = 1.0
# w_HB_DTLA1_s11_n77_a0 = 1.0
# w_HB_DTLA1_s11_n78_a0 = 1.0
# w_HB_DTLA1_s11_n79_a0 = 1.0
# w_HB_DTLA1_s11_n80_a0 = 1.0
# w_HB_DTLA1_s11_n81_a0 = 1.0
# w_HB_DTLA1_s11_n82_a0 = 1.0
# w_HB_DTLA1_s11_n83_a0 = 1.0
# w_HB_DTLA1_s11_n84_a0 = 1.0
# w_HB_DTLA1_s11_n85_a0 = 1.0
# w_HB_DTLA1_s11_n86_a0 = 1.0
# w_HB_DTLA1_s11_n87_a0 = 1.0
# w_HB_DTLA1_s11_n88_a0 = 1.0
# w_HB_DTLA1_s11_n89_a0 = 1.0
# w_HB_DTLA1_s11_n90_a0 = 1.0
# w_HB_DTLA1_s11_n91_a0 = 1.0
# w_HB_DTLA1_s11_n92_a0 = 1.0
# w_HB_DTLA1_s11_n93_a0 = 1.0
# w_HB_DTLA1_s11_n94_a0 = 1.0
# w_HB_DTLA1_s11_n95_a0 = 1.0
# w_HB_DTLA1_s11_n96_a0 = 1.0
# w_HB_DTLA1_s11_n97_a0 = 1.0
# w_HB_DTLA1_s11_n98_a0 = 1.0
# w_HB_DTLA1_s11_n99_a0 = 1.0
# w_HB_DTLA1_s12_n32_a0 = 1.0
# w_HB_DTLA1_s12_n33_a0 = 1.0
# w_HB_DTLA1_s12_n34_a0 = 1.0
# w_HB_DTLA1_s12_n35_a0 = 1.0
# w_HB_DTLA1_s12_n36_a0 = 1.0
# w_HB_DTLA1_s12_n37_a0 = 1.0
# w_HB_DTLA1_s12_n38_a0 = 1.0
# w_HB_DTLA1_s12_n39_a0 = 1.0
# w_HB_DTLA1_s12_n40_a0 = 1.0
# w_HB_DTLA1_s12_n41_a0 = 1.0
# w_HB_DTLA1_s12_n42_a0 = 1.0
# w_HB_DTLA1_s12_n43_a0 = 1.0
# w_HB_DTLA1_s12_n44_a0 = 1.0
# w_HB_DTLA1_s12_n45_a0 = 1.0
# w_HB_DTLA1_s12_n46_a0 = 1.0
# w_HB_DTLA1_s12_n47_a0 = 1.0
# w_HB_DTLA1_s12_n48_a0 = 1.0
# w_HB_DTLA1_s12_n49_a0 = 1.0
# w_HB_DTLA1_s12_n50_a0 = 1.0
# w_HB_DTLA1_s12_n51_a0 = 1.0
# w_HB_DTLA1_s12_n52_a0 = 1.0
# w_HB_DTLA1_s12_n53_a0 = 1.0
# w_HB_DTLA1_s12_n54_a0 = 1.0
# w_HB_DTLA1_s12_n55_a0 = 1.0
# w_HB_DTLA1_s12_n56_a0 = 1.0
# w_HB_DTLA1_s12_n57_a0 = 1.0
# w_HB_DTLA1_s12_n58_a0 = 1.0
# w_HB_DTLA1_s12_n59_a0 = 1.0
# w_HB_DTLA1_s12_n60_a0 = 1.0
# w_HB_DTLA1_s12_n61_a0 = 1.0
# w_HB_DTLA1_s12_n62_a0 = 1.0
# w_HB_DTLA1_s12_n63_a0 = 1.0
# w_HB_DTLA1_s12_n64_a0 = 1.0
# w_HB_DTLA1_s12_n65_a0 = 1.0
# w_HB_DTLA1_s12_n66_a0 = 1.0
# w_HB_DTLA1_s12_n67_a0 = 1.0
# w_HB_DTLA1_s12_n68_a0 = 1.0
# w_HB_DTLA1_s12_n69_a0 = 1.0
# w_HB_DTLA1_s12_n70_a0 = 1.0
# w_HB_DTLA1_s12_n71_a0 = 1.0
# w_HB_DTLA1_s12_n72_a0 = 1.0
# w_HB_DTLA1_s12_n73_a0 = 1.0
# w_HB_DTLA1_s12_n74_a0 = 1.0
# w_HB_DTLA1_s12_n75_a0 = 1.0
# w_HB_DTLA1_s12_n76_a0 = 1.0
# w_HB_DTLA1_s12_n77_a0 = 1.0
# w_HB_DTLA1_s12_n78_a0 = 1.0
# w_HB_DTLA1_s12_n79_a0 = 1.0
# w_HB_DTLA1_s12_n80_a0 = 1.0
# w_HB_DTLA1_s12_n81_a0 = 1.0
# w_HB_DTLA1_s12_n82_a0 = 1.0
# w_HB_DTLA1_s12_n83_a0 = 1.0
# w_HB_DTLA1_s12_n84_a0 = 1.0
# w_HB_DTLA1_s12_n85_a0 = 1.0
# w_HB_DTLA1_s12_n86_a0 = 1.0
# w_HB_DTLA1_s12_n87_a0 = 1.0
# w_HB_DTLA1_s12_n88_a0 = 1.0
# w_HB_DTLA1_s12_n89_a0 = 1.0
# w_HB_DTLA1_s12_n90_a0 = 1.0
# w_HB_DTLA1_s12_n91_a0 = 1.0
# w_HB_DTLA1_s12_n92_a0 = 1.0
# w_HB_DTLA1_s12_n93_a0 = 1.0
# w_HB_DTLA1_s12_n94_a0 = 1.0
# w_HB_DTLA1_s12_n95_a0 = 1.0
# w_HB_DTLA1_s12_n96_a0 = 1.0
# w_HB_DTLA1_s12_n97_a0 = 1.0
# w_HB_DTLA1_s12_n98_a0 = 1.0
# w_HB_DTLA1_s12_n99_a0 = 1.0
# w_HB_DTLA1_s13_n33_a0 = 1.0
# w_HB_DTLA1_s13_n34_a0 = 1.0
# w_HB_DTLA1_s13_n35_a0 = 1.0
# w_HB_DTLA1_s13_n36_a0 = 1.0
# w_HB_DTLA1_s13_n37_a0 = 1.0
# w_HB_DTLA1_s13_n38_a0 = 1.0
# w_HB_DTLA1_s13_n39_a0 = 1.0
# w_HB_DTLA1_s13_n40_a0 = 1.0
# w_HB_DTLA1_s13_n41_a0 = 1.0
# w_HB_DTLA1_s13_n42_a0 = 1.0
# w_HB_DTLA1_s13_n43_a0 = 1.0
# w_HB_DTLA1_s13_n44_a0 = 1.0
# w_HB_DTLA1_s13_n45_a0 = 1.0
# w_HB_DTLA1_s13_n46_a0 = 1.0
# w_HB_DTLA1_s13_n47_a0 = 1.0
# w_HB_DTLA1_s13_n48_a0 = 1.0
# w_HB_DTLA1_s13_n49_a0 = 1.0
# w_HB_DTLA1_s13_n50_a0 = 1.0
# w_HB_DTLA1_s13_n51_a0 = 1.0
# w_HB_DTLA1_s13_n52_a0 = 1.0
# w_HB_DTLA1_s13_n53_a0 = 1.0
# w_HB_DTLA1_s13_n54_a0 = 1.0
# w_HB_DTLA1_s13_n55_a0 = 1.0
# w_HB_DTLA1_s13_n56_a0 = 1.0
# w_HB_DTLA1_s13_n57_a0 = 1.0
# w_HB_DTLA1_s13_n58_a0 = 1.0
# w_HB_DTLA1_s13_n59_a0 = 1.0
# w_HB_DTLA1_s13_n60_a0 = 1.0
# w_HB_DTLA1_s13_n61_a0 = 1.0
# w_HB_DTLA1_s13_n62_a0 = 1.0
# w_HB_DTLA1_s13_n63_a0 = 1.0
# w_HB_DTLA1_s13_n64_a0 = 1.0
# w_HB_DTLA1_s13_n65_a0 = 1.0
# w_HB_DTLA1_s13_n66_a0 = 1.0
# w_HB_DTLA1_s13_n67_a0 = 1.0
# w_HB_DTLA1_s13_n68_a0 = 1.0
# w_HB_DTLA1_s13_n69_a0 = 1.0
# w_HB_DTLA1_s13_n70_a0 = 1.0
# w_HB_DTLA1_s13_n71_a0 = 1.0
# w_HB_DTLA1_s13_n72_a0 = 1.0
# w_HB_DTLA1_s13_n73_a0 = 1.0
# w_HB_DTLA1_s13_n74_a0 = 1.0
# w_HB_DTLA1_s13_n75_a0 = 1.0
# w_HB_DTLA1_s13_n76_a0 = 1.0
# w_HB_DTLA1_s13_n77_a0 = 1.0
# w_HB_DTLA1_s13_n78_a0 = 1.0
# w_HB_DTLA1_s13_n79_a0 = 1.0
# w_HB_DTLA1_s13_n80_a0 = 1.0
# w_HB_DTLA1_s13_n81_a0 = 1.0
# w_HB_DTLA1_s13_n82_a0 = 1.0
# w_HB_DTLA1_s13_n83_a0 = 1.0
# w_HB_DTLA1_s13_n84_a0 = 1.0
# w_HB_DTLA1_s13_n85_a0 = 1.0
# w_HB_DTLA1_s13_n86_a0 = 1.0
# w_HB_DTLA1_s13_n87_a0 = 1.0
# w_HB_DTLA1_s13_n88_a0 = 1.0
# w_HB_DTLA1_s13_n89_a0 = 1.0
# w_HB_DTLA1_s13_n90_a0 = 1.0
# w_HB_DTLA1_s13_n91_a0 = 1.0
# w_HB_DTLA1_s13_n92_a0 = 1.0
# w_HB_DTLA1_s13_n93_a0 = 1.0
# w_HB_DTLA1_s13_n94_a0 = 1.0
# w_HB_DTLA1_s13_n95_a0 = 1.0
# w_HB_DTLA1_s13_n96_a0 = 1.0
# w_HB_DTLA1_s13_n97_a0 = 1.0
# w_HB_DTLA1_s13_n98_a0 = 1.0
# w_HB_DTLA1_s13_n99_a0 = 1.0
# w_HB_DTLA1_s14_n34_a0 = 1.0
# w_HB_DTLA1_s14_n35_a0 = 1.0
# w_HB_DTLA1_s14_n36_a0 = 1.0
# w_HB_DTLA1_s14_n37_a0 = 1.0
# w_HB_DTLA1_s14_n38_a0 = 1.0
# w_HB_DTLA1_s14_n39_a0 = 1.0
# w_HB_DTLA1_s14_n40_a0 = 1.0
# w_HB_DTLA1_s14_n41_a0 = 1.0
# w_HB_DTLA1_s14_n42_a0 = 1.0
# w_HB_DTLA1_s14_n43_a0 = 1.0
# w_HB_DTLA1_s14_n44_a0 = 1.0
# w_HB_DTLA1_s14_n45_a0 = 1.0
# w_HB_DTLA1_s14_n46_a0 = 1.0
# w_HB_DTLA1_s14_n47_a0 = 1.0
# w_HB_DTLA1_s14_n48_a0 = 1.0
# w_HB_DTLA1_s14_n49_a0 = 1.0
# w_HB_DTLA1_s14_n50_a0 = 1.0
# w_HB_DTLA1_s14_n51_a0 = 1.0
# w_HB_DTLA1_s14_n52_a0 = 1.0
# w_HB_DTLA1_s14_n53_a0 = 1.0
# w_HB_DTLA1_s14_n54_a0 = 1.0
# w_HB_DTLA1_s14_n55_a0 = 1.0
# w_HB_DTLA1_s14_n56_a0 = 1.0
# w_HB_DTLA1_s14_n57_a0 = 1.0
# w_HB_DTLA1_s14_n58_a0 = 1.0
# w_HB_DTLA1_s14_n59_a0 = 1.0
# w_HB_DTLA1_s14_n60_a0 = 1.0
# w_HB_DTLA1_s14_n61_a0 = 1.0
# w_HB_DTLA1_s14_n62_a0 = 1.0
# w_HB_DTLA1_s14_n63_a0 = 1.0
# w_HB_DTLA1_s14_n64_a0 = 1.0
# w_HB_DTLA1_s14_n65_a0 = 1.0
# w_HB_DTLA1_s14_n66_a0 = 1.0
# w_HB_DTLA1_s14_n67_a0 = 1.0
# w_HB_DTLA1_s14_n68_a0 = 1.0
# w_HB_DTLA1_s14_n69_a0 = 1.0
# w_HB_DTLA1_s14_n70_a0 = 1.0
# w_HB_DTLA1_s14_n71_a0 = 1.0
# w_HB_DTLA1_s14_n72_a0 = 1.0
# w_HB_DTLA1_s14_n73_a0 = 1.0
# w_HB_DTLA1_s14_n74_a0 = 1.0
# w_HB_DTLA1_s14_n75_a0 = 1.0
# w_HB_DTLA1_s14_n76_a0 = 1.0
# w_HB_DTLA1_s14_n77_a0 = 1.0
# w_HB_DTLA1_s14_n78_a0 = 1.0
# w_HB_DTLA1_s14_n79_a0 = 1.0
# w_HB_DTLA1_s14_n80_a0 = 1.0
# w_HB_DTLA1_s14_n81_a0 = 1.0
# w_HB_DTLA1_s14_n82_a0 = 1.0
# w_HB_DTLA1_s14_n83_a0 = 1.0
# w_HB_DTLA1_s14_n84_a0 = 1.0
# w_HB_DTLA1_s14_n85_a0 = 1.0
# w_HB_DTLA1_s14_n86_a0 = 1.0
# w_HB_DTLA1_s14_n87_a0 = 1.0
# w_HB_DTLA1_s14_n88_a0 = 1.0
# w_HB_DTLA1_s14_n89_a0 = 1.0
# w_HB_DTLA1_s14_n90_a0 = 1.0
# w_HB_DTLA1_s14_n91_a0 = 1.0
# w_HB_DTLA1_s14_n92_a0 = 1.0
# w_HB_DTLA1_s14_n93_a0 = 1.0
# w_HB_DTLA1_s14_n94_a0 = 1.0
# w_HB_DTLA1_s14_n95_a0 = 1.0
# w_HB_DTLA1_s14_n96_a0 = 1.0
# w_HB_DTLA1_s14_n97_a0 = 1.0
# w_HB_DTLA1_s14_n98_a0 = 1.0
# w_HB_DTLA1_s14_n99_a0 = 1.0
# w_HB_DTLA1_s15_n35_a0 = 1.0
# w_HB_DTLA1_s15_n36_a0 = 1.0
# w_HB_DTLA1_s15_n37_a0 = 1.0
# w_HB_DTLA1_s15_n38_a0 = 1.0
# w_HB_DTLA1_s15_n39_a0 = 1.0
# w_HB_DTLA1_s15_n40_a0 = 1.0
# w_HB_DTLA1_s15_n41_a0 = 1.0
# w_HB_DTLA1_s15_n42_a0 = 1.0
# w_HB_DTLA1_s15_n43_a0 = 1.0
# w_HB_DTLA1_s15_n44_a0 = 1.0
# w_HB_DTLA1_s15_n45_a0 = 1.0
# w_HB_DTLA1_s15_n46_a0 = 1.0
# w_HB_DTLA1_s15_n47_a0 = 1.0
# w_HB_DTLA1_s15_n48_a0 = 1.0
# w_HB_DTLA1_s15_n49_a0 = 1.0
# w_HB_DTLA1_s15_n50_a0 = 1.0
# w_HB_DTLA1_s15_n51_a0 = 1.0
# w_HB_DTLA1_s15_n52_a0 = 1.0
# w_HB_DTLA1_s15_n53_a0 = 1.0
# w_HB_DTLA1_s15_n54_a0 = 1.0
# w_HB_DTLA1_s15_n55_a0 = 1.0
# w_HB_DTLA1_s15_n56_a0 = 1.0
# w_HB_DTLA1_s15_n57_a0 = 1.0
# w_HB_DTLA1_s15_n58_a0 = 1.0
# w_HB_DTLA1_s15_n59_a0 = 1.0
# w_HB_DTLA1_s15_n60_a0 = 1.0
# w_HB_DTLA1_s15_n61_a0 = 1.0
# w_HB_DTLA1_s15_n62_a0 = 1.0
# w_HB_DTLA1_s15_n63_a0 = 1.0
# w_HB_DTLA1_s15_n64_a0 = 1.0
# w_HB_DTLA1_s15_n65_a0 = 1.0
# w_HB_DTLA1_s15_n66_a0 = 1.0
# w_HB_DTLA1_s15_n67_a0 = 1.0
# w_HB_DTLA1_s15_n68_a0 = 1.0
# w_HB_DTLA1_s15_n69_a0 = 1.0
# w_HB_DTLA1_s15_n70_a0 = 1.0
# w_HB_DTLA1_s15_n71_a0 = 1.0
# w_HB_DTLA1_s15_n72_a0 = 1.0
# w_HB_DTLA1_s15_n73_a0 = 1.0
# w_HB_DTLA1_s15_n74_a0 = 1.0
# w_HB_DTLA1_s15_n75_a0 = 1.0
# w_HB_DTLA1_s15_n76_a0 = 1.0
# w_HB_DTLA1_s15_n77_a0 = 1.0
# w_HB_DTLA1_s15_n78_a0 = 1.0
# w_HB_DTLA1_s15_n79_a0 = 1.0
# w_HB_DTLA1_s15_n80_a0 = 1.0
# w_HB_DTLA1_s15_n81_a0 = 1.0
# w_HB_DTLA1_s15_n82_a0 = 1.0
# w_HB_DTLA1_s15_n83_a0 = 1.0
# w_HB_DTLA1_s15_n84_a0 = 1.0
# w_HB_DTLA1_s15_n85_a0 = 1.0
# w_HB_DTLA1_s15_n86_a0 = 1.0
# w_HB_DTLA1_s15_n87_a0 = 1.0
# w_HB_DTLA1_s15_n88_a0 = 1.0
# w_HB_DTLA1_s15_n89_a0 = 1.0
# w_HB_DTLA1_s15_n90_a0 = 1.0
# w_HB_DTLA1_s15_n91_a0 = 1.0
# w_HB_DTLA1_s15_n92_a0 = 1.0
# w_HB_DTLA1_s15_n93_a0 = 1.0
# w_HB_DTLA1_s15_n94_a0 = 1.0
# w_HB_DTLA1_s15_n95_a0 = 1.0
# w_HB_DTLA1_s15_n96_a0 = 1.0
# w_HB_DTLA1_s15_n97_a0 = 1.0
# w_HB_DTLA1_s15_n98_a0 = 1.0
# w_HB_DTLA1_s15_n99_a0 = 1.0
# w_HB_DTLA1_s1_n21_a0 = 1.0
# w_HB_DTLA1_s1_n22_a0 = 1.0
# w_HB_DTLA1_s1_n23_a0 = 1.0
# w_HB_DTLA1_s1_n24_a0 = 1.0
# w_HB_DTLA1_s1_n25_a0 = 1.0
# w_HB_DTLA1_s1_n26_a0 = 1.0
# w_HB_DTLA1_s1_n27_a0 = 1.0
# w_HB_DTLA1_s1_n28_a0 = 1.0
# w_HB_DTLA1_s1_n29_a0 = 1.0
# w_HB_DTLA1_s1_n30_a0 = 1.0
# w_HB_DTLA1_s1_n31_a0 = 1.0
# w_HB_DTLA1_s1_n32_a0 = 1.0
# w_HB_DTLA1_s1_n33_a0 = 1.0
# w_HB_DTLA1_s1_n34_a0 = 1.0
# w_HB_DTLA1_s1_n35_a0 = 1.0
# w_HB_DTLA1_s1_n36_a0 = 1.0
# w_HB_DTLA1_s1_n37_a0 = 1.0
# w_HB_DTLA1_s1_n38_a0 = 1.0
# w_HB_DTLA1_s1_n39_a0 = 1.0
# w_HB_DTLA1_s1_n40_a0 = 1.0
# w_HB_DTLA1_s1_n41_a0 = 1.0
# w_HB_DTLA1_s1_n42_a0 = 1.0
# w_HB_DTLA1_s1_n43_a0 = 1.0
# w_HB_DTLA1_s1_n44_a0 = 1.0
# w_HB_DTLA1_s1_n45_a0 = 1.0
# w_HB_DTLA1_s1_n46_a0 = 1.0
# w_HB_DTLA1_s1_n47_a0 = 1.0
# w_HB_DTLA1_s1_n48_a0 = 1.0
# w_HB_DTLA1_s1_n49_a0 = 1.0
# w_HB_DTLA1_s1_n50_a0 = 1.0
# w_HB_DTLA1_s1_n51_a0 = 1.0
# w_HB_DTLA1_s1_n52_a0 = 1.0
# w_HB_DTLA1_s1_n53_a0 = 1.0
# w_HB_DTLA1_s1_n54_a0 = 1.0
# w_HB_DTLA1_s1_n55_a0 = 1.0
# w_HB_DTLA1_s1_n56_a0 = 1.0
# w_HB_DTLA1_s1_n57_a0 = 1.0
# w_HB_DTLA1_s1_n58_a0 = 1.0
# w_HB_DTLA1_s1_n59_a0 = 1.0
# w_HB_DTLA1_s1_n60_a0 = 1.0
# w_HB_DTLA1_s1_n61_a0 = 1.0
# w_HB_DTLA1_s1_n62_a0 = 1.0
# w_HB_DTLA1_s1_n63_a0 = 1.0
# w_HB_DTLA1_s1_n64_a0 = 1.0
# w_HB_DTLA1_s1_n65_a0 = 1.0
# w_HB_DTLA1_s1_n66_a0 = 1.0
# w_HB_DTLA1_s1_n67_a0 = 1.0
# w_HB_DTLA1_s1_n68_a0 = 1.0
# w_HB_DTLA1_s1_n69_a0 = 1.0
# w_HB_DTLA1_s1_n70_a0 = 1.0
# w_HB_DTLA1_s1_n71_a0 = 1.0
# w_HB_DTLA1_s1_n72_a0 = 1.0
# w_HB_DTLA1_s1_n73_a0 = 1.0
# w_HB_DTLA1_s1_n74_a0 = 1.0
# w_HB_DTLA1_s1_n75_a0 = 1.0
# w_HB_DTLA1_s1_n76_a0 = 1.0
# w_HB_DTLA1_s1_n77_a0 = 1.0
# w_HB_DTLA1_s1_n78_a0 = 1.0
# w_HB_DTLA1_s1_n79_a0 = 1.0
# w_HB_DTLA1_s1_n80_a0 = 1.0
# w_HB_DTLA1_s1_n81_a0 = 1.0
# w_HB_DTLA1_s1_n82_a0 = 1.0
# w_HB_DTLA1_s1_n83_a0 = 1.0
# w_HB_DTLA1_s1_n84_a0 = 1.0
# w_HB_DTLA1_s1_n85_a0 = 1.0
# w_HB_DTLA1_s1_n86_a0 = 1.0
# w_HB_DTLA1_s1_n87_a0 = 1.0
# w_HB_DTLA1_s1_n88_a0 = 1.0
# w_HB_DTLA1_s1_n89_a0 = 1.0
# w_HB_DTLA1_s1_n90_a0 = 1.0
# w_HB_DTLA1_s1_n91_a0 = 1.0
# w_HB_DTLA1_s1_n92_a0 = 1.0
# w_HB_DTLA1_s1_n93_a0 = 1.0
# w_HB_DTLA1_s1_n94_a0 = 1.0
# w_HB_DTLA1_s1_n95_a0 = 1.0
# w_HB_DTLA1_s1_n96_a0 = 1.0
# w_HB_DTLA1_s1_n97_a0 = 1.0
# w_HB_DTLA1_s1_n98_a0 = 1.0
# w_HB_DTLA1_s1_n99_a0 = 1.0
# w_HB_DTLA1_s2_n22_a0 = 1.0
# w_HB_DTLA1_s2_n23_a0 = 1.0
# w_HB_DTLA1_s2_n24_a0 = 1.0
# w_HB_DTLA1_s2_n25_a0 = 1.0
# w_HB_DTLA1_s2_n26_a0 = 1.0
# w_HB_DTLA1_s2_n27_a0 = 1.0
# w_HB_DTLA1_s2_n28_a0 = 1.0
# w_HB_DTLA1_s2_n29_a0 = 1.0
# w_HB_DTLA1_s2_n30_a0 = 1.0
# w_HB_DTLA1_s2_n31_a0 = 1.0
# w_HB_DTLA1_s2_n32_a0 = 1.0
# w_HB_DTLA1_s2_n33_a0 = 1.0
# w_HB_DTLA1_s2_n34_a0 = 1.0
# w_HB_DTLA1_s2_n35_a0 = 1.0
# w_HB_DTLA1_s2_n36_a0 = 1.0
# w_HB_DTLA1_s2_n37_a0 = 1.0
# w_HB_DTLA1_s2_n38_a0 = 1.0
# w_HB_DTLA1_s2_n39_a0 = 1.0
# w_HB_DTLA1_s2_n40_a0 = 1.0
# w_HB_DTLA1_s2_n41_a0 = 1.0
# w_HB_DTLA1_s2_n42_a0 = 1.0
# w_HB_DTLA1_s2_n43_a0 = 1.0
# w_HB_DTLA1_s2_n44_a0 = 1.0
# w_HB_DTLA1_s2_n45_a0 = 1.0
# w_HB_DTLA1_s2_n46_a0 = 1.0
# w_HB_DTLA1_s2_n47_a0 = 1.0
# w_HB_DTLA1_s2_n48_a0 = 1.0
# w_HB_DTLA1_s2_n49_a0 = 1.0
# w_HB_DTLA1_s2_n50_a0 = 1.0
# w_HB_DTLA1_s2_n51_a0 = 1.0
# w_HB_DTLA1_s2_n52_a0 = 1.0
# w_HB_DTLA1_s2_n53_a0 = 1.0
# w_HB_DTLA1_s2_n54_a0 = 1.0
# w_HB_DTLA1_s2_n55_a0 = 1.0
# w_HB_DTLA1_s2_n56_a0 = 1.0
# w_HB_DTLA1_s2_n57_a0 = 1.0
# w_HB_DTLA1_s2_n58_a0 = 1.0
# w_HB_DTLA1_s2_n59_a0 = 1.0
# w_HB_DTLA1_s2_n60_a0 = 1.0
# w_HB_DTLA1_s2_n61_a0 = 1.0
# w_HB_DTLA1_s2_n62_a0 = 1.0
# w_HB_DTLA1_s2_n63_a0 = 1.0
# w_HB_DTLA1_s2_n64_a0 = 1.0
# w_HB_DTLA1_s2_n65_a0 = 1.0
# w_HB_DTLA1_s2_n66_a0 = 1.0
# w_HB_DTLA1_s2_n67_a0 = 1.0
# w_HB_DTLA1_s2_n68_a0 = 1.0
# w_HB_DTLA1_s2_n69_a0 = 1.0
# w_HB_DTLA1_s2_n70_a0 = 1.0
# w_HB_DTLA1_s2_n71_a0 = 1.0
# w_HB_DTLA1_s2_n72_a0 = 1.0
# w_HB_DTLA1_s2_n73_a0 = 1.0
# w_HB_DTLA1_s2_n74_a0 = 1.0
# w_HB_DTLA1_s2_n75_a0 = 1.0
# w_HB_DTLA1_s2_n76_a0 = 1.0
# w_HB_DTLA1_s2_n77_a0 = 1.0
# w_HB_DTLA1_s2_n78_a0 = 1.0
# w_HB_DTLA1_s2_n79_a0 = 1.0
# w_HB_DTLA1_s2_n80_a0 = 1.0
# w_HB_DTLA1_s2_n81_a0 = 1.0
# w_HB_DTLA1_s2_n82_a0 = 1.0
# w_HB_DTLA1_s2_n83_a0 = 1.0
# w_HB_DTLA1_s2_n84_a0 = 1.0
# w_HB_DTLA1_s2_n85_a0 = 1.0
# w_HB_DTLA1_s2_n86_a0 = 1.0
# w_HB_DTLA1_s2_n87_a0 = 1.0
# w_HB_DTLA1_s2_n88_a0 = 1.0
# w_HB_DTLA1_s2_n89_a0 = 1.0
# w_HB_DTLA1_s2_n90_a0 = 1.0
# w_HB_DTLA1_s2_n91_a0 = 1.0
# w_HB_DTLA1_s2_n92_a0 = 1.0
# w_HB_DTLA1_s2_n93_a0 = 1.0
# w_HB_DTLA1_s2_n94_a0 = 1.0
# w_HB_DTLA1_s2_n95_a0 = 1.0
# w_HB_DTLA1_s2_n96_a0 = 1.0
# w_HB_DTLA1_s2_n97_a0 = 1.0
# w_HB_DTLA1_s2_n98_a0 = 1.0
# w_HB_DTLA1_s2_n99_a0 = 1.0
# w_HB_DTLA1_s3_n23_a0 = 1.0
# w_HB_DTLA1_s3_n24_a0 = 1.0
# w_HB_DTLA1_s3_n25_a0 = 1.0
# w_HB_DTLA1_s3_n26_a0 = 1.0
# w_HB_DTLA1_s3_n27_a0 = 1.0
# w_HB_DTLA1_s3_n28_a0 = 1.0
# w_HB_DTLA1_s3_n29_a0 = 1.0
# w_HB_DTLA1_s3_n30_a0 = 1.0
# w_HB_DTLA1_s3_n31_a0 = 1.0
# w_HB_DTLA1_s3_n32_a0 = 1.0
# w_HB_DTLA1_s3_n33_a0 = 1.0
# w_HB_DTLA1_s3_n34_a0 = 1.0
# w_HB_DTLA1_s3_n35_a0 = 1.0
# w_HB_DTLA1_s3_n36_a0 = 1.0
# w_HB_DTLA1_s3_n37_a0 = 1.0
# w_HB_DTLA1_s3_n38_a0 = 1.0
# w_HB_DTLA1_s3_n39_a0 = 1.0
# w_HB_DTLA1_s3_n40_a0 = 1.0
# w_HB_DTLA1_s3_n41_a0 = 1.0
# w_HB_DTLA1_s3_n42_a0 = 1.0
# w_HB_DTLA1_s3_n43_a0 = 1.0
# w_HB_DTLA1_s3_n44_a0 = 1.0
# w_HB_DTLA1_s3_n45_a0 = 1.0
# w_HB_DTLA1_s3_n46_a0 = 1.0
# w_HB_DTLA1_s3_n47_a0 = 1.0
# w_HB_DTLA1_s3_n48_a0 = 1.0
# w_HB_DTLA1_s3_n49_a0 = 1.0
# w_HB_DTLA1_s3_n50_a0 = 1.0
# w_HB_DTLA1_s3_n51_a0 = 1.0
# w_HB_DTLA1_s3_n52_a0 = 1.0
# w_HB_DTLA1_s3_n53_a0 = 1.0
# w_HB_DTLA1_s3_n54_a0 = 1.0
# w_HB_DTLA1_s3_n55_a0 = 1.0
# w_HB_DTLA1_s3_n56_a0 = 1.0
# w_HB_DTLA1_s3_n57_a0 = 1.0
# w_HB_DTLA1_s3_n58_a0 = 1.0
# w_HB_DTLA1_s3_n59_a0 = 1.0
# w_HB_DTLA1_s3_n60_a0 = 1.0
# w_HB_DTLA1_s3_n61_a0 = 1.0
# w_HB_DTLA1_s3_n62_a0 = 1.0
# w_HB_DTLA1_s3_n63_a0 = 1.0
# w_HB_DTLA1_s3_n64_a0 = 1.0
# w_HB_DTLA1_s3_n65_a0 = 1.0
# w_HB_DTLA1_s3_n66_a0 = 1.0
# w_HB_DTLA1_s3_n67_a0 = 1.0
# w_HB_DTLA1_s3_n68_a0 = 1.0
# w_HB_DTLA1_s3_n69_a0 = 1.0
# w_HB_DTLA1_s3_n70_a0 = 1.0
# w_HB_DTLA1_s3_n71_a0 = 1.0
# w_HB_DTLA1_s3_n72_a0 = 1.0
# w_HB_DTLA1_s3_n73_a0 = 1.0
# w_HB_DTLA1_s3_n74_a0 = 1.0
# w_HB_DTLA1_s3_n75_a0 = 1.0
# w_HB_DTLA1_s3_n76_a0 = 1.0
# w_HB_DTLA1_s3_n77_a0 = 1.0
# w_HB_DTLA1_s3_n78_a0 = 1.0
# w_HB_DTLA1_s3_n79_a0 = 1.0
# w_HB_DTLA1_s3_n80_a0 = 1.0
# w_HB_DTLA1_s3_n81_a0 = 1.0
# w_HB_DTLA1_s3_n82_a0 = 1.0
# w_HB_DTLA1_s3_n83_a0 = 1.0
# w_HB_DTLA1_s3_n84_a0 = 1.0
# w_HB_DTLA1_s3_n85_a0 = 1.0
# w_HB_DTLA1_s3_n86_a0 = 1.0
# w_HB_DTLA1_s3_n87_a0 = 1.0
# w_HB_DTLA1_s3_n88_a0 = 1.0
# w_HB_DTLA1_s3_n89_a0 = 1.0
# w_HB_DTLA1_s3_n90_a0 = 1.0
# w_HB_DTLA1_s3_n91_a0 = 1.0
# w_HB_DTLA1_s3_n92_a0 = 1.0
# w_HB_DTLA1_s3_n93_a0 = 1.0
# w_HB_DTLA1_s3_n94_a0 = 1.0
# w_HB_DTLA1_s3_n95_a0 = 1.0
# w_HB_DTLA1_s3_n96_a0 = 1.0
# w_HB_DTLA1_s3_n97_a0 = 1.0
# w_HB_DTLA1_s3_n98_a0 = 1.0
# w_HB_DTLA1_s3_n99_a0 = 1.0
# w_HB_DTLA1_s4_n24_a0 = 1.0
# w_HB_DTLA1_s4_n25_a0 = 1.0
# w_HB_DTLA1_s4_n26_a0 = 1.0
# w_HB_DTLA1_s4_n27_a0 = 1.0
# w_HB_DTLA1_s4_n28_a0 = 1.0
# w_HB_DTLA1_s4_n29_a0 = 1.0
# w_HB_DTLA1_s4_n30_a0 = 1.0
# w_HB_DTLA1_s4_n31_a0 = 1.0
# w_HB_DTLA1_s4_n32_a0 = 1.0
# w_HB_DTLA1_s4_n33_a0 = 1.0
# w_HB_DTLA1_s4_n34_a0 = 1.0
# w_HB_DTLA1_s4_n35_a0 = 1.0
# w_HB_DTLA1_s4_n36_a0 = 1.0
# w_HB_DTLA1_s4_n37_a0 = 1.0
# w_HB_DTLA1_s4_n38_a0 = 1.0
# w_HB_DTLA1_s4_n39_a0 = 1.0
# w_HB_DTLA1_s4_n40_a0 = 1.0
# w_HB_DTLA1_s4_n41_a0 = 1.0
# w_HB_DTLA1_s4_n42_a0 = 1.0
# w_HB_DTLA1_s4_n43_a0 = 1.0
# w_HB_DTLA1_s4_n44_a0 = 1.0
# w_HB_DTLA1_s4_n45_a0 = 1.0
# w_HB_DTLA1_s4_n46_a0 = 1.0
# w_HB_DTLA1_s4_n47_a0 = 1.0
# w_HB_DTLA1_s4_n48_a0 = 1.0
# w_HB_DTLA1_s4_n49_a0 = 1.0
# w_HB_DTLA1_s4_n50_a0 = 1.0
# w_HB_DTLA1_s4_n51_a0 = 1.0
# w_HB_DTLA1_s4_n52_a0 = 1.0
# w_HB_DTLA1_s4_n53_a0 = 1.0
# w_HB_DTLA1_s4_n54_a0 = 1.0
# w_HB_DTLA1_s4_n55_a0 = 1.0
# w_HB_DTLA1_s4_n56_a0 = 1.0
# w_HB_DTLA1_s4_n57_a0 = 1.0
# w_HB_DTLA1_s4_n58_a0 = 1.0
# w_HB_DTLA1_s4_n59_a0 = 1.0
# w_HB_DTLA1_s4_n60_a0 = 1.0
# w_HB_DTLA1_s4_n61_a0 = 1.0
# w_HB_DTLA1_s4_n62_a0 = 1.0
# w_HB_DTLA1_s4_n63_a0 = 1.0
# w_HB_DTLA1_s4_n64_a0 = 1.0
# w_HB_DTLA1_s4_n65_a0 = 1.0
# w_HB_DTLA1_s4_n66_a0 = 1.0
# w_HB_DTLA1_s4_n67_a0 = 1.0
# w_HB_DTLA1_s4_n68_a0 = 1.0
# w_HB_DTLA1_s4_n69_a0 = 1.0
# w_HB_DTLA1_s4_n70_a0 = 1.0
# w_HB_DTLA1_s4_n71_a0 = 1.0
# w_HB_DTLA1_s4_n72_a0 = 1.0
# w_HB_DTLA1_s4_n73_a0 = 1.0
# w_HB_DTLA1_s4_n74_a0 = 1.0
# w_HB_DTLA1_s4_n75_a0 = 1.0
# w_HB_DTLA1_s4_n76_a0 = 1.0
# w_HB_DTLA1_s4_n77_a0 = 1.0
# w_HB_DTLA1_s4_n78_a0 = 1.0
# w_HB_DTLA1_s4_n79_a0 = 1.0
# w_HB_DTLA1_s4_n80_a0 = 1.0
# w_HB_DTLA1_s4_n81_a0 = 1.0
# w_HB_DTLA1_s4_n82_a0 = 1.0
# w_HB_DTLA1_s4_n83_a0 = 1.0
# w_HB_DTLA1_s4_n84_a0 = 1.0
# w_HB_DTLA1_s4_n85_a0 = 1.0
# w_HB_DTLA1_s4_n86_a0 = 1.0
# w_HB_DTLA1_s4_n87_a0 = 1.0
# w_HB_DTLA1_s4_n88_a0 = 1.0
# w_HB_DTLA1_s4_n89_a0 = 1.0
# w_HB_DTLA1_s4_n90_a0 = 1.0
# w_HB_DTLA1_s4_n91_a0 = 1.0
# w_HB_DTLA1_s4_n92_a0 = 1.0
# w_HB_DTLA1_s4_n93_a0 = 1.0
# w_HB_DTLA1_s4_n94_a0 = 1.0
# w_HB_DTLA1_s4_n95_a0 = 1.0
# w_HB_DTLA1_s4_n96_a0 = 1.0
# w_HB_DTLA1_s4_n97_a0 = 1.0
# w_HB_DTLA1_s4_n98_a0 = 1.0
# w_HB_DTLA1_s4_n99_a0 = 1.0
# w_HB_DTLA1_s5_n25_a0 = 1.0
# w_HB_DTLA1_s5_n26_a0 = 1.0
# w_HB_DTLA1_s5_n27_a0 = 1.0
# w_HB_DTLA1_s5_n28_a0 = 1.0
# w_HB_DTLA1_s5_n29_a0 = 1.0
# w_HB_DTLA1_s5_n30_a0 = 1.0
# w_HB_DTLA1_s5_n31_a0 = 1.0
# w_HB_DTLA1_s5_n32_a0 = 1.0
# w_HB_DTLA1_s5_n33_a0 = 1.0
# w_HB_DTLA1_s5_n34_a0 = 1.0
# w_HB_DTLA1_s5_n35_a0 = 1.0
# w_HB_DTLA1_s5_n36_a0 = 1.0
# w_HB_DTLA1_s5_n37_a0 = 1.0
# w_HB_DTLA1_s5_n38_a0 = 1.0
# w_HB_DTLA1_s5_n39_a0 = 1.0
# w_HB_DTLA1_s5_n40_a0 = 1.0
# w_HB_DTLA1_s5_n41_a0 = 1.0
# w_HB_DTLA1_s5_n42_a0 = 1.0
# w_HB_DTLA1_s5_n43_a0 = 1.0
# w_HB_DTLA1_s5_n44_a0 = 1.0
# w_HB_DTLA1_s5_n45_a0 = 1.0
# w_HB_DTLA1_s5_n46_a0 = 1.0
# w_HB_DTLA1_s5_n47_a0 = 1.0
# w_HB_DTLA1_s5_n48_a0 = 1.0
# w_HB_DTLA1_s5_n49_a0 = 1.0
# w_HB_DTLA1_s5_n50_a0 = 1.0
# w_HB_DTLA1_s5_n51_a0 = 1.0
# w_HB_DTLA1_s5_n52_a0 = 1.0
# w_HB_DTLA1_s5_n53_a0 = 1.0
# w_HB_DTLA1_s5_n54_a0 = 1.0
# w_HB_DTLA1_s5_n55_a0 = 1.0
# w_HB_DTLA1_s5_n56_a0 = 1.0
# w_HB_DTLA1_s5_n57_a0 = 1.0
# w_HB_DTLA1_s5_n58_a0 = 1.0
# w_HB_DTLA1_s5_n59_a0 = 1.0
# w_HB_DTLA1_s5_n60_a0 = 1.0
# w_HB_DTLA1_s5_n61_a0 = 1.0
# w_HB_DTLA1_s5_n62_a0 = 1.0
# w_HB_DTLA1_s5_n63_a0 = 1.0
# w_HB_DTLA1_s5_n64_a0 = 1.0
# w_HB_DTLA1_s5_n65_a0 = 1.0
# w_HB_DTLA1_s5_n66_a0 = 1.0
# w_HB_DTLA1_s5_n67_a0 = 1.0
# w_HB_DTLA1_s5_n68_a0 = 1.0
# w_HB_DTLA1_s5_n69_a0 = 1.0
# w_HB_DTLA1_s5_n70_a0 = 1.0
# w_HB_DTLA1_s5_n71_a0 = 1.0
# w_HB_DTLA1_s5_n72_a0 = 1.0
# w_HB_DTLA1_s5_n73_a0 = 1.0
# w_HB_DTLA1_s5_n74_a0 = 1.0
# w_HB_DTLA1_s5_n75_a0 = 1.0
# w_HB_DTLA1_s5_n76_a0 = 1.0
# w_HB_DTLA1_s5_n77_a0 = 1.0
# w_HB_DTLA1_s5_n78_a0 = 1.0
# w_HB_DTLA1_s5_n79_a0 = 1.0
# w_HB_DTLA1_s5_n80_a0 = 1.0
# w_HB_DTLA1_s5_n81_a0 = 1.0
# w_HB_DTLA1_s5_n82_a0 = 1.0
# w_HB_DTLA1_s5_n83_a0 = 1.0
# w_HB_DTLA1_s5_n84_a0 = 1.0
# w_HB_DTLA1_s5_n85_a0 = 1.0
# w_HB_DTLA1_s5_n86_a0 = 1.0
# w_HB_DTLA1_s5_n87_a0 = 1.0
# w_HB_DTLA1_s5_n88_a0 = 1.0
# w_HB_DTLA1_s5_n89_a0 = 1.0
# w_HB_DTLA1_s5_n90_a0 = 1.0
# w_HB_DTLA1_s5_n91_a0 = 1.0
# w_HB_DTLA1_s5_n92_a0 = 1.0
# w_HB_DTLA1_s5_n93_a0 = 1.0
# w_HB_DTLA1_s5_n94_a0 = 1.0
# w_HB_DTLA1_s5_n95_a0 = 1.0
# w_HB_DTLA1_s5_n96_a0 = 1.0
# w_HB_DTLA1_s5_n97_a0 = 1.0
# w_HB_DTLA1_s5_n98_a0 = 1.0
# w_HB_DTLA1_s5_n99_a0 = 1.0
# w_HB_DTLA1_s6_n26_a0 = 1.0
# w_HB_DTLA1_s6_n27_a0 = 1.0
# w_HB_DTLA1_s6_n28_a0 = 1.0
# w_HB_DTLA1_s6_n29_a0 = 1.0
# w_HB_DTLA1_s6_n30_a0 = 1.0
# w_HB_DTLA1_s6_n31_a0 = 1.0
# w_HB_DTLA1_s6_n32_a0 = 1.0
# w_HB_DTLA1_s6_n33_a0 = 1.0
# w_HB_DTLA1_s6_n34_a0 = 1.0
# w_HB_DTLA1_s6_n35_a0 = 1.0
# w_HB_DTLA1_s6_n36_a0 = 1.0
# w_HB_DTLA1_s6_n37_a0 = 1.0
# w_HB_DTLA1_s6_n38_a0 = 1.0
# w_HB_DTLA1_s6_n39_a0 = 1.0
# w_HB_DTLA1_s6_n40_a0 = 1.0
# w_HB_DTLA1_s6_n41_a0 = 1.0
# w_HB_DTLA1_s6_n42_a0 = 1.0
# w_HB_DTLA1_s6_n43_a0 = 1.0
# w_HB_DTLA1_s6_n44_a0 = 1.0
# w_HB_DTLA1_s6_n45_a0 = 1.0
# w_HB_DTLA1_s6_n46_a0 = 1.0
# w_HB_DTLA1_s6_n47_a0 = 1.0
# w_HB_DTLA1_s6_n48_a0 = 1.0
# w_HB_DTLA1_s6_n49_a0 = 1.0
# w_HB_DTLA1_s6_n50_a0 = 1.0
# w_HB_DTLA1_s6_n51_a0 = 1.0
# w_HB_DTLA1_s6_n52_a0 = 1.0
# w_HB_DTLA1_s6_n53_a0 = 1.0
# w_HB_DTLA1_s6_n54_a0 = 1.0
# w_HB_DTLA1_s6_n55_a0 = 1.0
# w_HB_DTLA1_s6_n56_a0 = 1.0
# w_HB_DTLA1_s6_n57_a0 = 1.0
# w_HB_DTLA1_s6_n58_a0 = 1.0
# w_HB_DTLA1_s6_n59_a0 = 1.0
# w_HB_DTLA1_s6_n60_a0 = 1.0
# w_HB_DTLA1_s6_n61_a0 = 1.0
# w_HB_DTLA1_s6_n62_a0 = 1.0
# w_HB_DTLA1_s6_n63_a0 = 1.0
# w_HB_DTLA1_s6_n64_a0 = 1.0
# w_HB_DTLA1_s6_n65_a0 = 1.0
# w_HB_DTLA1_s6_n66_a0 = 1.0
# w_HB_DTLA1_s6_n67_a0 = 1.0
# w_HB_DTLA1_s6_n68_a0 = 1.0
# w_HB_DTLA1_s6_n69_a0 = 1.0
# w_HB_DTLA1_s6_n70_a0 = 1.0
# w_HB_DTLA1_s6_n71_a0 = 1.0
# w_HB_DTLA1_s6_n72_a0 = 1.0
# w_HB_DTLA1_s6_n73_a0 = 1.0
# w_HB_DTLA1_s6_n74_a0 = 1.0
# w_HB_DTLA1_s6_n75_a0 = 1.0
# w_HB_DTLA1_s6_n76_a0 = 1.0
# w_HB_DTLA1_s6_n77_a0 = 1.0
# w_HB_DTLA1_s6_n78_a0 = 1.0
# w_HB_DTLA1_s6_n79_a0 = 1.0
# w_HB_DTLA1_s6_n80_a0 = 1.0
# w_HB_DTLA1_s6_n81_a0 = 1.0
# w_HB_DTLA1_s6_n82_a0 = 1.0
# w_HB_DTLA1_s6_n83_a0 = 1.0
# w_HB_DTLA1_s6_n84_a0 = 1.0
# w_HB_DTLA1_s6_n85_a0 = 1.0
# w_HB_DTLA1_s6_n86_a0 = 1.0
# w_HB_DTLA1_s6_n87_a0 = 1.0
# w_HB_DTLA1_s6_n88_a0 = 1.0
# w_HB_DTLA1_s6_n89_a0 = 1.0
# w_HB_DTLA1_s6_n90_a0 = 1.0
# w_HB_DTLA1_s6_n91_a0 = 1.0
# w_HB_DTLA1_s6_n92_a0 = 1.0
# w_HB_DTLA1_s6_n93_a0 = 1.0
# w_HB_DTLA1_s6_n94_a0 = 1.0
# w_HB_DTLA1_s6_n95_a0 = 1.0
# w_HB_DTLA1_s6_n96_a0 = 1.0
# w_HB_DTLA1_s6_n97_a0 = 1.0
# w_HB_DTLA1_s6_n98_a0 = 1.0
# w_HB_DTLA1_s6_n99_a0 = 1.0
# w_HB_DTLA1_s7_n27_a0 = 1.0
# w_HB_DTLA1_s7_n28_a0 = 1.0
# w_HB_DTLA1_s7_n29_a0 = 1.0
# w_HB_DTLA1_s7_n30_a0 = 1.0
# w_HB_DTLA1_s7_n31_a0 = 1.0
# w_HB_DTLA1_s7_n32_a0 = 1.0
# w_HB_DTLA1_s7_n33_a0 = 1.0
# w_HB_DTLA1_s7_n34_a0 = 1.0
# w_HB_DTLA1_s7_n35_a0 = 1.0
# w_HB_DTLA1_s7_n36_a0 = 1.0
# w_HB_DTLA1_s7_n37_a0 = 1.0
# w_HB_DTLA1_s7_n38_a0 = 1.0
# w_HB_DTLA1_s7_n39_a0 = 1.0
# w_HB_DTLA1_s7_n40_a0 = 1.0
# w_HB_DTLA1_s7_n41_a0 = 1.0
# w_HB_DTLA1_s7_n42_a0 = 1.0
# w_HB_DTLA1_s7_n43_a0 = 1.0
# w_HB_DTLA1_s7_n44_a0 = 1.0
# w_HB_DTLA1_s7_n45_a0 = 1.0
# w_HB_DTLA1_s7_n46_a0 = 1.0
# w_HB_DTLA1_s7_n47_a0 = 1.0
# w_HB_DTLA1_s7_n48_a0 = 1.0
# w_HB_DTLA1_s7_n49_a0 = 1.0
# w_HB_DTLA1_s7_n50_a0 = 1.0
# w_HB_DTLA1_s7_n51_a0 = 1.0
# w_HB_DTLA1_s7_n52_a0 = 1.0
# w_HB_DTLA1_s7_n53_a0 = 1.0
# w_HB_DTLA1_s7_n54_a0 = 1.0
# w_HB_DTLA1_s7_n55_a0 = 1.0
# w_HB_DTLA1_s7_n56_a0 = 1.0
# w_HB_DTLA1_s7_n57_a0 = 1.0
# w_HB_DTLA1_s7_n58_a0 = 1.0
# w_HB_DTLA1_s7_n59_a0 = 1.0
# w_HB_DTLA1_s7_n60_a0 = 1.0
# w_HB_DTLA1_s7_n61_a0 = 1.0
# w_HB_DTLA1_s7_n62_a0 = 1.0
# w_HB_DTLA1_s7_n63_a0 = 1.0
# w_HB_DTLA1_s7_n64_a0 = 1.0
# w_HB_DTLA1_s7_n65_a0 = 1.0
# w_HB_DTLA1_s7_n66_a0 = 1.0
# w_HB_DTLA1_s7_n67_a0 = 1.0
# w_HB_DTLA1_s7_n68_a0 = 1.0
# w_HB_DTLA1_s7_n69_a0 = 1.0
# w_HB_DTLA1_s7_n70_a0 = 1.0
# w_HB_DTLA1_s7_n71_a0 = 1.0
# w_HB_DTLA1_s7_n72_a0 = 1.0
# w_HB_DTLA1_s7_n73_a0 = 1.0
# w_HB_DTLA1_s7_n74_a0 = 1.0
# w_HB_DTLA1_s7_n75_a0 = 1.0
# w_HB_DTLA1_s7_n76_a0 = 1.0
# w_HB_DTLA1_s7_n77_a0 = 1.0
# w_HB_DTLA1_s7_n78_a0 = 1.0
# w_HB_DTLA1_s7_n79_a0 = 1.0
# w_HB_DTLA1_s7_n80_a0 = 1.0
# w_HB_DTLA1_s7_n81_a0 = 1.0
# w_HB_DTLA1_s7_n82_a0 = 1.0
# w_HB_DTLA1_s7_n83_a0 = 1.0
# w_HB_DTLA1_s7_n84_a0 = 1.0
# w_HB_DTLA1_s7_n85_a0 = 1.0
# w_HB_DTLA1_s7_n86_a0 = 1.0
# w_HB_DTLA1_s7_n87_a0 = 1.0
# w_HB_DTLA1_s7_n88_a0 = 1.0
# w_HB_DTLA1_s7_n89_a0 = 1.0
# w_HB_DTLA1_s7_n90_a0 = 1.0
# w_HB_DTLA1_s7_n91_a0 = 1.0
# w_HB_DTLA1_s7_n92_a0 = 1.0
# w_HB_DTLA1_s7_n93_a0 = 1.0
# w_HB_DTLA1_s7_n94_a0 = 1.0
# w_HB_DTLA1_s7_n95_a0 = 1.0
# w_HB_DTLA1_s7_n96_a0 = 1.0
# w_HB_DTLA1_s7_n97_a0 = 1.0
# w_HB_DTLA1_s7_n98_a0 = 1.0
# w_HB_DTLA1_s7_n99_a0 = 1.0
# w_HB_DTLA1_s8_n28_a0 = 1.0
# w_HB_DTLA1_s8_n29_a0 = 1.0
# w_HB_DTLA1_s8_n30_a0 = 1.0
# w_HB_DTLA1_s8_n31_a0 = 1.0
# w_HB_DTLA1_s8_n32_a0 = 1.0
# w_HB_DTLA1_s8_n33_a0 = 1.0
# w_HB_DTLA1_s8_n34_a0 = 1.0
# w_HB_DTLA1_s8_n35_a0 = 1.0
# w_HB_DTLA1_s8_n36_a0 = 1.0
# w_HB_DTLA1_s8_n37_a0 = 1.0
# w_HB_DTLA1_s8_n38_a0 = 1.0
# w_HB_DTLA1_s8_n39_a0 = 1.0
# w_HB_DTLA1_s8_n40_a0 = 1.0
# w_HB_DTLA1_s8_n41_a0 = 1.0
# w_HB_DTLA1_s8_n42_a0 = 1.0
# w_HB_DTLA1_s8_n43_a0 = 1.0
# w_HB_DTLA1_s8_n44_a0 = 1.0
# w_HB_DTLA1_s8_n45_a0 = 1.0
# w_HB_DTLA1_s8_n46_a0 = 1.0
# w_HB_DTLA1_s8_n47_a0 = 1.0
# w_HB_DTLA1_s8_n48_a0 = 1.0
# w_HB_DTLA1_s8_n49_a0 = 1.0
# w_HB_DTLA1_s8_n50_a0 = 1.0
# w_HB_DTLA1_s8_n51_a0 = 1.0
# w_HB_DTLA1_s8_n52_a0 = 1.0
# w_HB_DTLA1_s8_n53_a0 = 1.0
# w_HB_DTLA1_s8_n54_a0 = 1.0
# w_HB_DTLA1_s8_n55_a0 = 1.0
# w_HB_DTLA1_s8_n56_a0 = 1.0
# w_HB_DTLA1_s8_n57_a0 = 1.0
# w_HB_DTLA1_s8_n58_a0 = 1.0
# w_HB_DTLA1_s8_n59_a0 = 1.0
# w_HB_DTLA1_s8_n60_a0 = 1.0
# w_HB_DTLA1_s8_n61_a0 = 1.0
# w_HB_DTLA1_s8_n62_a0 = 1.0
# w_HB_DTLA1_s8_n63_a0 = 1.0
# w_HB_DTLA1_s8_n64_a0 = 1.0
# w_HB_DTLA1_s8_n65_a0 = 1.0
# w_HB_DTLA1_s8_n66_a0 = 1.0
# w_HB_DTLA1_s8_n67_a0 = 1.0
# w_HB_DTLA1_s8_n68_a0 = 1.0
# w_HB_DTLA1_s8_n69_a0 = 1.0
# w_HB_DTLA1_s8_n70_a0 = 1.0
# w_HB_DTLA1_s8_n71_a0 = 1.0
# w_HB_DTLA1_s8_n72_a0 = 1.0
# w_HB_DTLA1_s8_n73_a0 = 1.0
# w_HB_DTLA1_s8_n74_a0 = 1.0
# w_HB_DTLA1_s8_n75_a0 = 1.0
# w_HB_DTLA1_s8_n76_a0 = 1.0
# w_HB_DTLA1_s8_n77_a0 = 1.0
# w_HB_DTLA1_s8_n78_a0 = 1.0
# w_HB_DTLA1_s8_n79_a0 = 1.0
# w_HB_DTLA1_s8_n80_a0 = 1.0
# w_HB_DTLA1_s8_n81_a0 = 1.0
# w_HB_DTLA1_s8_n82_a0 = 1.0
# w_HB_DTLA1_s8_n83_a0 = 1.0
# w_HB_DTLA1_s8_n84_a0 = 1.0
# w_HB_DTLA1_s8_n85_a0 = 1.0
# w_HB_DTLA1_s8_n86_a0 = 1.0
# w_HB_DTLA1_s8_n87_a0 = 1.0
# w_HB_DTLA1_s8_n88_a0 = 1.0
# w_HB_DTLA1_s8_n89_a0 = 1.0
# w_HB_DTLA1_s8_n90_a0 = 1.0
# w_HB_DTLA1_s8_n91_a0 = 1.0
# w_HB_DTLA1_s8_n92_a0 = 1.0
# w_HB_DTLA1_s8_n93_a0 = 1.0
# w_HB_DTLA1_s8_n94_a0 = 1.0
# w_HB_DTLA1_s8_n95_a0 = 1.0
# w_HB_DTLA1_s8_n96_a0 = 1.0
# w_HB_DTLA1_s8_n97_a0 = 1.0
# w_HB_DTLA1_s8_n98_a0 = 1.0
# w_HB_DTLA1_s8_n99_a0 = 1.0
# w_HB_DTLA1_s9_n29_a0 = 1.0
# w_HB_DTLA1_s9_n30_a0 = 1.0
# w_HB_DTLA1_s9_n31_a0 = 1.0
# w_HB_DTLA1_s9_n32_a0 = 1.0
# w_HB_DTLA1_s9_n33_a0 = 1.0
# w_HB_DTLA1_s9_n34_a0 = 1.0
# w_HB_DTLA1_s9_n35_a0 = 1.0
# w_HB_DTLA1_s9_n36_a0 = 1.0
# w_HB_DTLA1_s9_n37_a0 = 1.0
# w_HB_DTLA1_s9_n38_a0 = 1.0
# w_HB_DTLA1_s9_n39_a0 = 1.0
# w_HB_DTLA1_s9_n40_a0 = 1.0
# w_HB_DTLA1_s9_n41_a0 = 1.0
# w_HB_DTLA1_s9_n42_a0 = 1.0
# w_HB_DTLA1_s9_n43_a0 = 1.0
# w_HB_DTLA1_s9_n44_a0 = 1.0
# w_HB_DTLA1_s9_n45_a0 = 1.0
# w_HB_DTLA1_s9_n46_a0 = 1.0
# w_HB_DTLA1_s9_n47_a0 = 1.0
# w_HB_DTLA1_s9_n48_a0 = 1.0
# w_HB_DTLA1_s9_n49_a0 = 1.0
# w_HB_DTLA1_s9_n50_a0 = 1.0
# w_HB_DTLA1_s9_n51_a0 = 1.0
# w_HB_DTLA1_s9_n52_a0 = 1.0
# w_HB_DTLA1_s9_n53_a0 = 1.0
# w_HB_DTLA1_s9_n54_a0 = 1.0
# w_HB_DTLA1_s9_n55_a0 = 1.0
# w_HB_DTLA1_s9_n56_a0 = 1.0
# w_HB_DTLA1_s9_n57_a0 = 1.0
# w_HB_DTLA1_s9_n58_a0 = 1.0
# w_HB_DTLA1_s9_n59_a0 = 1.0
# w_HB_DTLA1_s9_n60_a0 = 1.0
# w_HB_DTLA1_s9_n61_a0 = 1.0
# w_HB_DTLA1_s9_n62_a0 = 1.0
# w_HB_DTLA1_s9_n63_a0 = 1.0
# w_HB_DTLA1_s9_n64_a0 = 1.0
# w_HB_DTLA1_s9_n65_a0 = 1.0
# w_HB_DTLA1_s9_n66_a0 = 1.0
# w_HB_DTLA1_s9_n67_a0 = 1.0
# w_HB_DTLA1_s9_n68_a0 = 1.0
# w_HB_DTLA1_s9_n69_a0 = 1.0
# w_HB_DTLA1_s9_n70_a0 = 1.0
# w_HB_DTLA1_s9_n71_a0 = 1.0
# w_HB_DTLA1_s9_n72_a0 = 1.0
# w_HB_DTLA1_s9_n73_a0 = 1.0
# w_HB_DTLA1_s9_n74_a0 = 1.0
# w_HB_DTLA1_s9_n75_a0 = 1.0
# w_HB_DTLA1_s9_n76_a0 = 1.0
# w_HB_DTLA1_s9_n77_a0 = 1.0
# w_HB_DTLA1_s9_n78_a0 = 1.0
# w_HB_DTLA1_s9_n79_a0 = 1.0
# w_HB_DTLA1_s9_n80_a0 = 1.0
# w_HB_DTLA1_s9_n81_a0 = 1.0
# w_HB_DTLA1_s9_n82_a0 = 1.0
# w_HB_DTLA1_s9_n83_a0 = 1.0
# w_HB_DTLA1_s9_n84_a0 = 1.0
# w_HB_DTLA1_s9_n85_a0 = 1.0
# w_HB_DTLA1_s9_n86_a0 = 1.0
# w_HB_DTLA1_s9_n87_a0 = 1.0
# w_HB_DTLA1_s9_n88_a0 = 1.0
# w_HB_DTLA1_s9_n89_a0 = 1.0
# w_HB_DTLA1_s9_n90_a0 = 1.0
# w_HB_DTLA1_s9_n91_a0 = 1.0
# w_HB_DTLA1_s9_n92_a0 = 1.0
# w_HB_DTLA1_s9_n93_a0 = 1.0
# w_HB_DTLA1_s9_n94_a0 = 1.0
# w_HB_DTLA1_s9_n95_a0 = 1.0
# w_HB_DTLA1_s9_n96_a0 = 1.0
# w_HB_DTLA1_s9_n97_a0 = 1.0
# w_HB_DTLA1_s9_n98_a0 = 1.0
# w_HB_DTLA1_s9_n99_a0 = 1.0
# w_LB_DTLA2_s0_n11_a3 = 1.0
# w_LB_DTLA2_s0_n12_a3 = 1.0
# w_LB_DTLA2_s0_n13_a3 = 1.0
# w_LB_DTLA2_s0_n14_a3 = 1.0
# w_LB_DTLA2_s0_n15_a3 = 1.0
# w_LB_DTLA2_s0_n16_a3 = 1.0
# w_LB_DTLA2_s0_n17_a3 = 1.0
# w_LB_DTLA2_s0_n18_a3 = 1.0
# w_LB_DTLA2_s0_n19_a3 = 1.0
# w_LB_DTLA2_s0_n20_a3 = 1.0
# w_LB_DTLA2_s0_n21_a3 = 1.0
# w_LB_DTLA2_s0_n22_a3 = 1.0
# w_LB_DTLA2_s0_n23_a3 = 1.0
# w_LB_DTLA2_s0_n24_a3 = 1.0
# w_LB_DTLA2_s0_n25_a3 = 1.0
# w_LB_DTLA2_s0_n26_a3 = 1.0
# w_LB_DTLA2_s0_n27_a3 = 1.0
# w_LB_DTLA2_s0_n28_a3 = 1.0
# w_LB_DTLA2_s0_n29_a3 = 1.0
# w_LB_DTLA2_s0_n30_a3 = 1.0
# w_LB_DTLA2_s0_n31_a3 = 1.0
# w_LB_DTLA2_s0_n32_a3 = 1.0
# w_LB_DTLA2_s0_n33_a3 = 1.0
# w_LB_DTLA2_s0_n34_a3 = 1.0
# w_LB_DTLA2_s0_n35_a3 = 1.0
# w_LB_DTLA2_s0_n36_a3 = 1.0
# w_LB_DTLA2_s0_n37_a3 = 1.0
# w_LB_DTLA2_s0_n38_a3 = 1.0
# w_LB_DTLA2_s0_n39_a3 = 1.0
# w_LB_DTLA2_s0_n40_a3 = 1.0
# w_LB_DTLA2_s0_n41_a3 = 1.0
# w_LB_DTLA2_s0_n42_a3 = 1.0
# w_LB_DTLA2_s0_n43_a3 = 1.0
# w_LB_DTLA2_s0_n44_a3 = 1.0
# w_LB_DTLA2_s0_n45_a3 = 1.0
# w_LB_DTLA2_s0_n46_a3 = 1.0
# w_LB_DTLA2_s0_n47_a3 = 1.0
# w_LB_DTLA2_s0_n48_a3 = 1.0
# w_LB_DTLA2_s0_n49_a3 = 1.0
# w_LB_DTLA2_s0_n50_a3 = 1.0
# w_LB_DTLA2_s0_n51_a3 = 1.0
# w_LB_DTLA2_s0_n52_a3 = 1.0
# w_LB_DTLA2_s0_n53_a3 = 1.0
# w_LB_DTLA2_s0_n54_a3 = 1.0
# w_LB_DTLA2_s0_n55_a3 = 1.0
# w_LB_DTLA2_s0_n56_a3 = 1.0
# w_LB_DTLA2_s0_n57_a3 = 1.0
# w_LB_DTLA2_s0_n58_a3 = 1.0
# w_LB_DTLA2_s0_n59_a3 = 1.0
# w_LB_DTLA2_s0_n60_a3 = 1.0
# w_LB_DTLA2_s0_n61_a3 = 1.0
# w_LB_DTLA2_s0_n62_a3 = 1.0
# w_LB_DTLA2_s0_n63_a3 = 1.0
# w_LB_DTLA2_s0_n64_a3 = 1.0
# w_LB_DTLA2_s0_n65_a3 = 1.0
# w_LB_DTLA2_s0_n66_a3 = 1.0
# w_LB_DTLA2_s0_n67_a3 = 1.0
# w_LB_DTLA2_s0_n68_a3 = 1.0
# w_LB_DTLA2_s0_n69_a3 = 1.0
# w_LB_DTLA2_s0_n70_a3 = 1.0
# w_LB_DTLA2_s0_n71_a3 = 1.0
# w_LB_DTLA2_s0_n72_a3 = 1.0
# w_LB_DTLA2_s0_n73_a3 = 1.0
# w_LB_DTLA2_s0_n74_a3 = 1.0
# w_LB_DTLA2_s0_n75_a3 = 1.0
# w_LB_DTLA2_s0_n76_a3 = 1.0
# w_LB_DTLA2_s0_n77_a3 = 1.0
# w_LB_DTLA2_s0_n78_a3 = 1.0
# w_LB_DTLA2_s0_n79_a3 = 1.0
# w_LB_DTLA2_s0_n80_a3 = 1.0
# w_LB_DTLA2_s0_n81_a3 = 1.0
# w_LB_DTLA2_s0_n82_a3 = 1.0
# w_LB_DTLA2_s0_n83_a3 = 1.0
# w_LB_DTLA2_s0_n84_a3 = 1.0
# w_LB_DTLA2_s0_n85_a3 = 1.0
# w_LB_DTLA2_s0_n86_a3 = 1.0
# w_LB_DTLA2_s0_n87_a3 = 1.0
# w_LB_DTLA2_s0_n88_a3 = 1.0
# w_LB_DTLA2_s0_n89_a3 = 1.0
# w_LB_DTLA2_s0_n90_a3 = 1.0
# w_LB_DTLA2_s0_n91_a3 = 1.0
# w_LB_DTLA2_s0_n92_a3 = 1.0
# w_LB_DTLA2_s0_n93_a3 = 1.0
# w_LB_DTLA2_s0_n94_a3 = 1.0
# w_LB_DTLA2_s0_n95_a3 = 1.0
# w_LB_DTLA2_s0_n96_a3 = 1.0
# w_LB_DTLA2_s0_n97_a3 = 1.0
# w_LB_DTLA2_s0_n98_a3 = 1.0
# w_LB_DTLA2_s0_n99_a3 = 1.0
# w_LB_DTLA2_s10_n21_a3 = 1.0
# w_LB_DTLA2_s10_n22_a3 = 1.0
# w_LB_DTLA2_s10_n23_a3 = 1.0
# w_LB_DTLA2_s10_n24_a3 = 1.0
# w_LB_DTLA2_s10_n25_a3 = 1.0
# w_LB_DTLA2_s10_n26_a3 = 1.0
# w_LB_DTLA2_s10_n27_a3 = 1.0
# w_LB_DTLA2_s10_n28_a3 = 1.0
# w_LB_DTLA2_s10_n29_a3 = 1.0
# w_LB_DTLA2_s10_n30_a3 = 1.0
# w_LB_DTLA2_s10_n31_a3 = 1.0
# w_LB_DTLA2_s10_n32_a3 = 1.0
# w_LB_DTLA2_s10_n33_a3 = 1.0
# w_LB_DTLA2_s10_n34_a3 = 1.0
# w_LB_DTLA2_s10_n35_a3 = 1.0
# w_LB_DTLA2_s10_n36_a3 = 1.0
# w_LB_DTLA2_s10_n37_a3 = 1.0
# w_LB_DTLA2_s10_n38_a3 = 1.0
# w_LB_DTLA2_s10_n39_a3 = 1.0
# w_LB_DTLA2_s10_n40_a3 = 1.0
# w_LB_DTLA2_s10_n41_a3 = 1.0
# w_LB_DTLA2_s10_n42_a3 = 1.0
# w_LB_DTLA2_s10_n43_a3 = 1.0
# w_LB_DTLA2_s10_n44_a3 = 1.0
# w_LB_DTLA2_s10_n45_a3 = 1.0
# w_LB_DTLA2_s10_n46_a3 = 1.0
# w_LB_DTLA2_s10_n47_a3 = 1.0
# w_LB_DTLA2_s10_n48_a3 = 1.0
# w_LB_DTLA2_s10_n49_a3 = 1.0
# w_LB_DTLA2_s10_n50_a3 = 1.0
# w_LB_DTLA2_s10_n51_a3 = 1.0
# w_LB_DTLA2_s10_n52_a3 = 1.0
# w_LB_DTLA2_s10_n53_a3 = 1.0
# w_LB_DTLA2_s10_n54_a3 = 1.0
# w_LB_DTLA2_s10_n55_a3 = 1.0
# w_LB_DTLA2_s10_n56_a3 = 1.0
# w_LB_DTLA2_s10_n57_a3 = 1.0
# w_LB_DTLA2_s10_n58_a3 = 1.0
# w_LB_DTLA2_s10_n59_a3 = 1.0
# w_LB_DTLA2_s10_n60_a3 = 1.0
# w_LB_DTLA2_s10_n61_a3 = 1.0
# w_LB_DTLA2_s10_n62_a3 = 1.0
# w_LB_DTLA2_s10_n63_a3 = 1.0
# w_LB_DTLA2_s10_n64_a3 = 1.0
# w_LB_DTLA2_s10_n65_a3 = 1.0
# w_LB_DTLA2_s10_n66_a3 = 1.0
# w_LB_DTLA2_s10_n67_a3 = 1.0
# w_LB_DTLA2_s10_n68_a3 = 1.0
# w_LB_DTLA2_s10_n69_a3 = 1.0
# w_LB_DTLA2_s10_n70_a3 = 1.0
# w_LB_DTLA2_s10_n71_a3 = 1.0
# w_LB_DTLA2_s10_n72_a3 = 1.0
# w_LB_DTLA2_s10_n73_a3 = 1.0
# w_LB_DTLA2_s10_n74_a3 = 1.0
# w_LB_DTLA2_s10_n75_a3 = 1.0
# w_LB_DTLA2_s10_n76_a3 = 1.0
# w_LB_DTLA2_s10_n77_a3 = 1.0
# w_LB_DTLA2_s10_n78_a3 = 1.0
# w_LB_DTLA2_s10_n79_a3 = 1.0
# w_LB_DTLA2_s10_n80_a3 = 1.0
# w_LB_DTLA2_s10_n81_a3 = 1.0
# w_LB_DTLA2_s10_n82_a3 = 1.0
# w_LB_DTLA2_s10_n83_a3 = 1.0
# w_LB_DTLA2_s10_n84_a3 = 1.0
# w_LB_DTLA2_s10_n85_a3 = 1.0
# w_LB_DTLA2_s10_n86_a3 = 1.0
# w_LB_DTLA2_s10_n87_a3 = 1.0
# w_LB_DTLA2_s10_n88_a3 = 1.0
# w_LB_DTLA2_s10_n89_a3 = 1.0
# w_LB_DTLA2_s10_n90_a3 = 1.0
# w_LB_DTLA2_s10_n91_a3 = 1.0
# w_LB_DTLA2_s10_n92_a3 = 1.0
# w_LB_DTLA2_s10_n93_a3 = 1.0
# w_LB_DTLA2_s10_n94_a3 = 1.0
# w_LB_DTLA2_s10_n95_a3 = 1.0
# w_LB_DTLA2_s10_n96_a3 = 1.0
# w_LB_DTLA2_s10_n97_a3 = 1.0
# w_LB_DTLA2_s10_n98_a3 = 1.0
# w_LB_DTLA2_s10_n99_a3 = 1.0
# w_LB_DTLA2_s11_n22_a3 = 1.0
# w_LB_DTLA2_s11_n23_a3 = 1.0
# w_LB_DTLA2_s11_n24_a3 = 1.0
# w_LB_DTLA2_s11_n25_a3 = 1.0
# w_LB_DTLA2_s11_n26_a3 = 1.0
# w_LB_DTLA2_s11_n27_a3 = 1.0
# w_LB_DTLA2_s11_n28_a3 = 1.0
# w_LB_DTLA2_s11_n29_a3 = 1.0
# w_LB_DTLA2_s11_n30_a3 = 1.0
# w_LB_DTLA2_s11_n31_a3 = 1.0
# w_LB_DTLA2_s11_n32_a3 = 1.0
# w_LB_DTLA2_s11_n33_a3 = 1.0
# w_LB_DTLA2_s11_n34_a3 = 1.0
# w_LB_DTLA2_s11_n35_a3 = 1.0
# w_LB_DTLA2_s11_n36_a3 = 1.0
# w_LB_DTLA2_s11_n37_a3 = 1.0
# w_LB_DTLA2_s11_n38_a3 = 1.0
# w_LB_DTLA2_s11_n39_a3 = 1.0
# w_LB_DTLA2_s11_n40_a3 = 1.0
# w_LB_DTLA2_s11_n41_a3 = 1.0
# w_LB_DTLA2_s11_n42_a3 = 1.0
# w_LB_DTLA2_s11_n43_a3 = 1.0
# w_LB_DTLA2_s11_n44_a3 = 1.0
# w_LB_DTLA2_s11_n45_a3 = 1.0
# w_LB_DTLA2_s11_n46_a3 = 1.0
# w_LB_DTLA2_s11_n47_a3 = 1.0
# w_LB_DTLA2_s11_n48_a3 = 1.0
# w_LB_DTLA2_s11_n49_a3 = 1.0
# w_LB_DTLA2_s11_n50_a3 = 1.0
# w_LB_DTLA2_s11_n51_a3 = 1.0
# w_LB_DTLA2_s11_n52_a3 = 1.0
# w_LB_DTLA2_s11_n53_a3 = 1.0
# w_LB_DTLA2_s11_n54_a3 = 1.0
# w_LB_DTLA2_s11_n55_a3 = 1.0
# w_LB_DTLA2_s11_n56_a3 = 1.0
# w_LB_DTLA2_s11_n57_a3 = 1.0
# w_LB_DTLA2_s11_n58_a3 = 1.0
# w_LB_DTLA2_s11_n59_a3 = 1.0
# w_LB_DTLA2_s11_n60_a3 = 1.0
# w_LB_DTLA2_s11_n61_a3 = 1.0
# w_LB_DTLA2_s11_n62_a3 = 1.0
# w_LB_DTLA2_s11_n63_a3 = 1.0
# w_LB_DTLA2_s11_n64_a3 = 1.0
# w_LB_DTLA2_s11_n65_a3 = 1.0
# w_LB_DTLA2_s11_n66_a3 = 1.0
# w_LB_DTLA2_s11_n67_a3 = 1.0
# w_LB_DTLA2_s11_n68_a3 = 1.0
# w_LB_DTLA2_s11_n69_a3 = 1.0
# w_LB_DTLA2_s11_n70_a3 = 1.0
# w_LB_DTLA2_s11_n71_a3 = 1.0
# w_LB_DTLA2_s11_n72_a3 = 1.0
# w_LB_DTLA2_s11_n73_a3 = 1.0
# w_LB_DTLA2_s11_n74_a3 = 1.0
# w_LB_DTLA2_s11_n75_a3 = 1.0
# w_LB_DTLA2_s11_n76_a3 = 1.0
# w_LB_DTLA2_s11_n77_a3 = 1.0
# w_LB_DTLA2_s11_n78_a3 = 1.0
# w_LB_DTLA2_s11_n79_a3 = 1.0
# w_LB_DTLA2_s11_n80_a3 = 1.0
# w_LB_DTLA2_s11_n81_a3 = 1.0
# w_LB_DTLA2_s11_n82_a3 = 1.0
# w_LB_DTLA2_s11_n83_a3 = 1.0
# w_LB_DTLA2_s11_n84_a3 = 1.0
# w_LB_DTLA2_s11_n85_a3 = 1.0
# w_LB_DTLA2_s11_n86_a3 = 1.0
# w_LB_DTLA2_s11_n87_a3 = 1.0
# w_LB_DTLA2_s11_n88_a3 = 1.0
# w_LB_DTLA2_s11_n89_a3 = 1.0
# w_LB_DTLA2_s11_n90_a3 = 1.0
# w_LB_DTLA2_s11_n91_a3 = 1.0
# w_LB_DTLA2_s11_n92_a3 = 1.0
# w_LB_DTLA2_s11_n93_a3 = 1.0
# w_LB_DTLA2_s11_n94_a3 = 1.0
# w_LB_DTLA2_s11_n95_a3 = 1.0
# w_LB_DTLA2_s11_n96_a3 = 1.0
# w_LB_DTLA2_s11_n97_a3 = 1.0
# w_LB_DTLA2_s11_n98_a3 = 1.0
# w_LB_DTLA2_s11_n99_a3 = 1.0
# w_LB_DTLA2_s12_n23_a3 = 1.0
# w_LB_DTLA2_s12_n24_a3 = 1.0
# w_LB_DTLA2_s12_n25_a3 = 1.0
# w_LB_DTLA2_s12_n26_a3 = 1.0
# w_LB_DTLA2_s12_n27_a3 = 1.0
# w_LB_DTLA2_s12_n28_a3 = 1.0
# w_LB_DTLA2_s12_n29_a3 = 1.0
# w_LB_DTLA2_s12_n30_a3 = 1.0
# w_LB_DTLA2_s12_n31_a3 = 1.0
# w_LB_DTLA2_s12_n32_a3 = 1.0
# w_LB_DTLA2_s12_n33_a3 = 1.0
# w_LB_DTLA2_s12_n34_a3 = 1.0
# w_LB_DTLA2_s12_n35_a3 = 1.0
# w_LB_DTLA2_s12_n36_a3 = 1.0
# w_LB_DTLA2_s12_n37_a3 = 1.0
# w_LB_DTLA2_s12_n38_a3 = 1.0
# w_LB_DTLA2_s12_n39_a3 = 1.0
# w_LB_DTLA2_s12_n40_a3 = 1.0
# w_LB_DTLA2_s12_n41_a3 = 1.0
# w_LB_DTLA2_s12_n42_a3 = 1.0
# w_LB_DTLA2_s12_n43_a3 = 1.0
# w_LB_DTLA2_s12_n44_a3 = 1.0
# w_LB_DTLA2_s12_n45_a3 = 1.0
# w_LB_DTLA2_s12_n46_a3 = 1.0
# w_LB_DTLA2_s12_n47_a3 = 1.0
# w_LB_DTLA2_s12_n48_a3 = 1.0
# w_LB_DTLA2_s12_n49_a3 = 1.0
# w_LB_DTLA2_s12_n50_a3 = 1.0
# w_LB_DTLA2_s12_n51_a3 = 1.0
# w_LB_DTLA2_s12_n52_a3 = 1.0
# w_LB_DTLA2_s12_n53_a3 = 1.0
# w_LB_DTLA2_s12_n54_a3 = 1.0
# w_LB_DTLA2_s12_n55_a3 = 1.0
# w_LB_DTLA2_s12_n56_a3 = 1.0
# w_LB_DTLA2_s12_n57_a3 = 1.0
# w_LB_DTLA2_s12_n58_a3 = 1.0
# w_LB_DTLA2_s12_n59_a3 = 1.0
# w_LB_DTLA2_s12_n60_a3 = 1.0
# w_LB_DTLA2_s12_n61_a3 = 1.0
# w_LB_DTLA2_s12_n62_a3 = 1.0
# w_LB_DTLA2_s12_n63_a3 = 1.0
# w_LB_DTLA2_s12_n64_a3 = 1.0
# w_LB_DTLA2_s12_n65_a3 = 1.0
# w_LB_DTLA2_s12_n66_a3 = 1.0
# w_LB_DTLA2_s12_n67_a3 = 1.0
# w_LB_DTLA2_s12_n68_a3 = 1.0
# w_LB_DTLA2_s12_n69_a3 = 1.0
# w_LB_DTLA2_s12_n70_a3 = 1.0
# w_LB_DTLA2_s12_n71_a3 = 1.0
# w_LB_DTLA2_s12_n72_a3 = 1.0
# w_LB_DTLA2_s12_n73_a3 = 1.0
# w_LB_DTLA2_s12_n74_a3 = 1.0
# w_LB_DTLA2_s12_n75_a3 = 1.0
# w_LB_DTLA2_s12_n76_a3 = 1.0
# w_LB_DTLA2_s12_n77_a3 = 1.0
# w_LB_DTLA2_s12_n78_a3 = 1.0
# w_LB_DTLA2_s12_n79_a3 = 1.0
# w_LB_DTLA2_s12_n80_a3 = 1.0
# w_LB_DTLA2_s12_n81_a3 = 1.0
# w_LB_DTLA2_s12_n82_a3 = 1.0
# w_LB_DTLA2_s12_n83_a3 = 1.0
# w_LB_DTLA2_s12_n84_a3 = 1.0
# w_LB_DTLA2_s12_n85_a3 = 1.0
# w_LB_DTLA2_s12_n86_a3 = 1.0
# w_LB_DTLA2_s12_n87_a3 = 1.0
# w_LB_DTLA2_s12_n88_a3 = 1.0
# w_LB_DTLA2_s12_n89_a3 = 1.0
# w_LB_DTLA2_s12_n90_a3 = 1.0
# w_LB_DTLA2_s12_n91_a3 = 1.0
# w_LB_DTLA2_s12_n92_a3 = 1.0
# w_LB_DTLA2_s12_n93_a3 = 1.0
# w_LB_DTLA2_s12_n94_a3 = 1.0
# w_LB_DTLA2_s12_n95_a3 = 1.0
# w_LB_DTLA2_s12_n96_a3 = 1.0
# w_LB_DTLA2_s12_n97_a3 = 1.0
# w_LB_DTLA2_s12_n98_a3 = 1.0
# w_LB_DTLA2_s12_n99_a3 = 1.0
# w_LB_DTLA2_s13_n24_a3 = 1.0
# w_LB_DTLA2_s13_n25_a3 = 1.0
# w_LB_DTLA2_s13_n26_a3 = 1.0
# w_LB_DTLA2_s13_n27_a3 = 1.0
# w_LB_DTLA2_s13_n28_a3 = 1.0
# w_LB_DTLA2_s13_n29_a3 = 1.0
# w_LB_DTLA2_s13_n30_a3 = 1.0
# w_LB_DTLA2_s13_n31_a3 = 1.0
# w_LB_DTLA2_s13_n32_a3 = 1.0
# w_LB_DTLA2_s13_n33_a3 = 1.0
# w_LB_DTLA2_s13_n34_a3 = 1.0
# w_LB_DTLA2_s13_n35_a3 = 1.0
# w_LB_DTLA2_s13_n36_a3 = 1.0
# w_LB_DTLA2_s13_n37_a3 = 1.0
# w_LB_DTLA2_s13_n38_a3 = 1.0
# w_LB_DTLA2_s13_n39_a3 = 1.0
# w_LB_DTLA2_s13_n40_a3 = 1.0
# w_LB_DTLA2_s13_n41_a3 = 1.0
# w_LB_DTLA2_s13_n42_a3 = 1.0
# w_LB_DTLA2_s13_n43_a3 = 1.0
# w_LB_DTLA2_s13_n44_a3 = 1.0
# w_LB_DTLA2_s13_n45_a3 = 1.0
# w_LB_DTLA2_s13_n46_a3 = 1.0
# w_LB_DTLA2_s13_n47_a3 = 1.0
# w_LB_DTLA2_s13_n48_a3 = 1.0
# w_LB_DTLA2_s13_n49_a3 = 1.0
# w_LB_DTLA2_s13_n50_a3 = 1.0
# w_LB_DTLA2_s13_n51_a3 = 1.0
# w_LB_DTLA2_s13_n52_a3 = 1.0
# w_LB_DTLA2_s13_n53_a3 = 1.0
# w_LB_DTLA2_s13_n54_a3 = 1.0
# w_LB_DTLA2_s13_n55_a3 = 1.0
# w_LB_DTLA2_s13_n56_a3 = 1.0
# w_LB_DTLA2_s13_n57_a3 = 1.0
# w_LB_DTLA2_s13_n58_a3 = 1.0
# w_LB_DTLA2_s13_n59_a3 = 1.0
# w_LB_DTLA2_s13_n60_a3 = 1.0
# w_LB_DTLA2_s13_n61_a3 = 1.0
# w_LB_DTLA2_s13_n62_a3 = 1.0
# w_LB_DTLA2_s13_n63_a3 = 1.0
# w_LB_DTLA2_s13_n64_a3 = 1.0
# w_LB_DTLA2_s13_n65_a3 = 1.0
# w_LB_DTLA2_s13_n66_a3 = 1.0
# w_LB_DTLA2_s13_n67_a3 = 1.0
# w_LB_DTLA2_s13_n68_a3 = 1.0
# w_LB_DTLA2_s13_n69_a3 = 1.0
# w_LB_DTLA2_s13_n70_a3 = 1.0
# w_LB_DTLA2_s13_n71_a3 = 1.0
# w_LB_DTLA2_s13_n72_a3 = 1.0
# ...
# w_LB_DTLA2_s6_n39_a3 = 1.0
# w_LB_DTLA2_s6_n40_a3 = 1.0
# w_LB_DTLA2_s6_n41_a3 = 1.0
# w_LB_DTLA2_s6_n42_a3 = 1.0
# w_LB_DTLA2_s6_n43_a3 = 1.0
# w_LB_DTLA2_s6_n44_a3 = 1.0
# w_LB_DTLA2_s6_n45_a3 = 1.0
# w_LB_DTLA2_s6_n46_a3 = 1.0
# w_LB_DTLA2_s6_n47_a3 = 1.0
# w_LB_DTLA2_s6_n48_a3 = 1.0
# w_LB_DTLA2_s6_n49_a3 = 1.0
# w_LB_DTLA2_s6_n50_a3 = 1.0
# w_LB_DTLA2_s6_n51_a3 = 1.0
# w_LB_DTLA2_s6_n52_a3 = 1.0
# w_LB_DTLA2_s6_n53_a3 = 1.0
# w_LB_DTLA2_s6_n54_a3 = 1.0
# w_LB_DTLA2_s6_n55_a3 = 1.0
# w_LB_DTLA2_s6_n56_a3 = 1.0
# w_LB_DTLA2_s6_n57_a3 = 1.0
# w_LB_DTLA2_s6_n58_a3 = 1.0
# w_LB_DTLA2_s6_n59_a3 = 1.0
# w_LB_DTLA2_s6_n60_a3 = 1.0
# w_LB_DTLA2_s6_n61_a3 = 1.0
# w_LB_DTLA2_s6_n62_a3 = 1.0
# w_LB_DTLA2_s6_n63_a3 = 1.0
# w_LB_DTLA2_s6_n64_a3 = 1.0
# w_LB_DTLA2_s6_n65_a3 = 1.0
# w_LB_DTLA2_s6_n66_a3 = 1.0
# w_LB_DTLA2_s6_n67_a3 = 1.0
# w_LB_DTLA2_s6_n68_a3 = 1.0
# w_LB_DTLA2_s6_n69_a3 = 1.0
# w_LB_DTLA2_s6_n70_a3 = 1.0
# w_LB_DTLA2_s6_n71_a3 = 1.0
# w_LB_DTLA2_s6_n72_a3 = 1.0
# w_LB_DTLA2_s6_n73_a3 = 1.0
# w_LB_DTLA2_s6_n74_a3 = 1.0
# w_LB_DTLA2_s6_n75_a3 = 1.0
# w_LB_DTLA2_s6_n76_a3 = 1.0
# w_LB_DTLA2_s6_n77_a3 = 1.0
# w_LB_DTLA2_s6_n78_a3 = 1.0
# w_LB_DTLA2_s6_n79_a3 = 1.0
# w_LB_DTLA2_s6_n80_a3 = 1.0
# w_LB_DTLA2_s6_n81_a3 = 1.0
# w_LB_DTLA2_s6_n82_a3 = 1.0
# w_LB_DTLA2_s6_n83_a3 = 1.0
# w_LB_DTLA2_s6_n84_a3 = 1.0
# w_LB_DTLA2_s6_n85_a3 = 1.0
# w_LB_DTLA2_s6_n86_a3 = 1.0
# w_LB_DTLA2_s6_n87_a3 = 1.0
# w_LB_DTLA2_s6_n88_a3 = 1.0
# w_LB_DTLA2_s6_n89_a3 = 1.0
# w_LB_DTLA2_s6_n90_a3 = 1.0
# w_LB_DTLA2_s6_n91_a3 = 1.0
# w_LB_DTLA2_s6_n92_a3 = 1.0
# w_LB_DTLA2_s6_n93_a3 = 1.0
# w_LB_DTLA2_s6_n94_a3 = 1.0
# w_LB_DTLA2_s6_n95_a3 = 1.0
# w_LB_DTLA2_s6_n96_a3 = 1.0
# w_LB_DTLA2_s6_n97_a3 = 1.0
# w_LB_DTLA2_s6_n98_a3 = 1.0
# w_LB_DTLA2_s6_n99_a3 = 1.0
# w_LB_DTLA2_s7_n18_a3 = 1.0
# w_LB_DTLA2_s7_n19_a3 = 1.0
# w_LB_DTLA2_s7_n20_a3 = 1.0
# w_LB_DTLA2_s7_n21_a3 = 1.0
# w_LB_DTLA2_s7_n22_a3 = 1.0
# w_LB_DTLA2_s7_n23_a3 = 1.0
# w_LB_DTLA2_s7_n24_a3 = 1.0
# w_LB_DTLA2_s7_n25_a3 = 1.0
# w_LB_DTLA2_s7_n26_a3 = 1.0
# w_LB_DTLA2_s7_n27_a3 = 1.0
# w_LB_DTLA2_s7_n28_a3 = 1.0
# w_LB_DTLA2_s7_n29_a3 = 1.0
# w_LB_DTLA2_s7_n30_a3 = 1.0
# w_LB_DTLA2_s7_n31_a3 = 1.0
# w_LB_DTLA2_s7_n32_a3 = 1.0
# w_LB_DTLA2_s7_n33_a3 = 1.0
# w_LB_DTLA2_s7_n34_a3 = 1.0
# w_LB_DTLA2_s7_n35_a3 = 1.0
# w_LB_DTLA2_s7_n36_a3 = 1.0
# w_LB_DTLA2_s7_n37_a3 = 1.0
# w_LB_DTLA2_s7_n38_a3 = 1.0
# w_LB_DTLA2_s7_n39_a3 = 1.0
# w_LB_DTLA2_s7_n40_a3 = 1.0
# w_LB_DTLA2_s7_n41_a3 = 1.0
# w_LB_DTLA2_s7_n42_a3 = 1.0
# w_LB_DTLA2_s7_n43_a3 = 1.0
# w_LB_DTLA2_s7_n44_a3 = 1.0
# w_LB_DTLA2_s7_n45_a3 = 1.0
# w_LB_DTLA2_s7_n46_a3 = 1.0
# w_LB_DTLA2_s7_n47_a3 = 1.0
# w_LB_DTLA2_s7_n48_a3 = 1.0
# w_LB_DTLA2_s7_n49_a3 = 1.0
# w_LB_DTLA2_s7_n50_a3 = 1.0
# w_LB_DTLA2_s7_n51_a3 = 1.0
# w_LB_DTLA2_s7_n52_a3 = 1.0
# w_LB_DTLA2_s7_n53_a3 = 1.0
# w_LB_DTLA2_s7_n54_a3 = 1.0
# w_LB_DTLA2_s7_n55_a3 = 1.0
# w_LB_DTLA2_s7_n56_a3 = 1.0
# w_LB_DTLA2_s7_n57_a3 = 1.0
# w_LB_DTLA2_s7_n58_a3 = 1.0
# w_LB_DTLA2_s7_n59_a3 = 1.0
# w_LB_DTLA2_s7_n60_a3 = 1.0
# w_LB_DTLA2_s7_n61_a3 = 1.0
# w_LB_DTLA2_s7_n62_a3 = 1.0
# w_LB_DTLA2_s7_n63_a3 = 1.0
# w_LB_DTLA2_s7_n64_a3 = 1.0
# w_LB_DTLA2_s7_n65_a3 = 1.0
# w_LB_DTLA2_s7_n66_a3 = 1.0
# w_LB_DTLA2_s7_n67_a3 = 1.0
# w_LB_DTLA2_s7_n68_a3 = 1.0
# w_LB_DTLA2_s7_n69_a3 = 1.0
# w_LB_DTLA2_s7_n70_a3 = 1.0
# w_LB_DTLA2_s7_n71_a3 = 1.0
# w_LB_DTLA2_s7_n72_a3 = 1.0
# w_LB_DTLA2_s7_n73_a3 = 1.0
# w_LB_DTLA2_s7_n74_a3 = 1.0
# w_LB_DTLA2_s7_n75_a3 = 1.0
# w_LB_DTLA2_s7_n76_a3 = 1.0
# w_LB_DTLA2_s7_n77_a3 = 1.0
# w_LB_DTLA2_s7_n78_a3 = 1.0
# w_LB_DTLA2_s7_n79_a3 = 1.0
# w_LB_DTLA2_s7_n80_a3 = 1.0
# w_LB_DTLA2_s7_n81_a3 = 1.0
# w_LB_DTLA2_s7_n82_a3 = 1.0
# w_LB_DTLA2_s7_n83_a3 = 1.0
# w_LB_DTLA2_s7_n84_a3 = 1.0
# w_LB_DTLA2_s7_n85_a3 = 1.0
# w_LB_DTLA2_s7_n86_a3 = 1.0
# w_LB_DTLA2_s7_n87_a3 = 1.0
# w_LB_DTLA2_s7_n88_a3 = 1.0
# w_LB_DTLA2_s7_n89_a3 = 1.0
# w_LB_DTLA2_s7_n90_a3 = 1.0
# w_LB_DTLA2_s7_n91_a3 = 1.0
# w_LB_DTLA2_s7_n92_a3 = 1.0
# w_LB_DTLA2_s7_n93_a3 = 1.0
# w_LB_DTLA2_s7_n94_a3 = 1.0
# w_LB_DTLA2_s7_n95_a3 = 1.0
# w_LB_DTLA2_s7_n96_a3 = 1.0
# w_LB_DTLA2_s7_n97_a3 = 1.0
# w_LB_DTLA2_s7_n98_a3 = 1.0
# w_LB_DTLA2_s7_n99_a3 = 1.0
# w_LB_DTLA2_s8_n19_a3 = 1.0
# w_LB_DTLA2_s8_n20_a3 = 1.0
# w_LB_DTLA2_s8_n21_a3 = 1.0
# w_LB_DTLA2_s8_n22_a3 = 1.0
# w_LB_DTLA2_s8_n23_a3 = 1.0
# w_LB_DTLA2_s8_n24_a3 = 1.0
# w_LB_DTLA2_s8_n25_a3 = 1.0
# w_LB_DTLA2_s8_n26_a3 = 1.0
# w_LB_DTLA2_s8_n27_a3 = 1.0
# w_LB_DTLA2_s8_n28_a3 = 1.0
# w_LB_DTLA2_s8_n29_a3 = 1.0
# w_LB_DTLA2_s8_n30_a3 = 1.0
# w_LB_DTLA2_s8_n31_a3 = 1.0
# w_LB_DTLA2_s8_n32_a3 = 1.0
# w_LB_DTLA2_s8_n33_a3 = 1.0
# w_LB_DTLA2_s8_n34_a3 = 1.0
# w_LB_DTLA2_s8_n35_a3 = 1.0
# w_LB_DTLA2_s8_n36_a3 = 1.0
# w_LB_DTLA2_s8_n37_a3 = 1.0
# w_LB_DTLA2_s8_n38_a3 = 1.0
# w_LB_DTLA2_s8_n39_a3 = 1.0
# w_LB_DTLA2_s8_n40_a3 = 1.0
# w_LB_DTLA2_s8_n41_a3 = 1.0
# w_LB_DTLA2_s8_n42_a3 = 1.0
# w_LB_DTLA2_s8_n43_a3 = 1.0
# w_LB_DTLA2_s8_n44_a3 = 1.0
# w_LB_DTLA2_s8_n45_a3 = 1.0
# w_LB_DTLA2_s8_n46_a3 = 1.0
# w_LB_DTLA2_s8_n47_a3 = 1.0
# w_LB_DTLA2_s8_n48_a3 = 1.0
# w_LB_DTLA2_s8_n49_a3 = 1.0
# w_LB_DTLA2_s8_n50_a3 = 1.0
# w_LB_DTLA2_s8_n51_a3 = 1.0
# w_LB_DTLA2_s8_n52_a3 = 1.0
# w_LB_DTLA2_s8_n53_a3 = 1.0
# w_LB_DTLA2_s8_n54_a3 = 1.0
# w_LB_DTLA2_s8_n55_a3 = 1.0
# w_LB_DTLA2_s8_n56_a3 = 1.0
# w_LB_DTLA2_s8_n57_a3 = 1.0
# w_LB_DTLA2_s8_n58_a3 = 1.0
# w_LB_DTLA2_s8_n59_a3 = 1.0
# w_LB_DTLA2_s8_n60_a3 = 1.0
# w_LB_DTLA2_s8_n61_a3 = 1.0
# w_LB_DTLA2_s8_n62_a3 = 1.0
# w_LB_DTLA2_s8_n63_a3 = 1.0
# w_LB_DTLA2_s8_n64_a3 = 1.0
# w_LB_DTLA2_s8_n65_a3 = 1.0
# w_LB_DTLA2_s8_n66_a3 = 1.0
# w_LB_DTLA2_s8_n67_a3 = 1.0
# w_LB_DTLA2_s8_n68_a3 = 1.0
# w_LB_DTLA2_s8_n69_a3 = 1.0
# w_LB_DTLA2_s8_n70_a3 = 1.0
# w_LB_DTLA2_s8_n71_a3 = 1.0
# w_LB_DTLA2_s8_n72_a3 = 1.0
# w_LB_DTLA2_s8_n73_a3 = 1.0
# w_LB_DTLA2_s8_n74_a3 = 1.0
# w_LB_DTLA2_s8_n75_a3 = 1.0
# w_LB_DTLA2_s8_n76_a3 = 1.0
# w_LB_DTLA2_s8_n77_a3 = 1.0
# w_LB_DTLA2_s8_n78_a3 = 1.0
# w_LB_DTLA2_s8_n79_a3 = 1.0
# w_LB_DTLA2_s8_n80_a3 = 1.0
# w_LB_DTLA2_s8_n81_a3 = 1.0
# w_LB_DTLA2_s8_n82_a3 = 1.0
# w_LB_DTLA2_s8_n83_a3 = 1.0
# w_LB_DTLA2_s8_n84_a3 = 1.0
# w_LB_DTLA2_s8_n85_a3 = 1.0
# w_LB_DTLA2_s8_n86_a3 = 1.0
# w_LB_DTLA2_s8_n87_a3 = 1.0
# w_LB_DTLA2_s8_n88_a3 = 1.0
# w_LB_DTLA2_s8_n89_a3 = 1.0
# w_LB_DTLA2_s8_n90_a3 = 1.0
# w_LB_DTLA2_s8_n91_a3 = 1.0
# w_LB_DTLA2_s8_n92_a3 = 1.0
# w_LB_DTLA2_s8_n93_a3 = 1.0
# w_LB_DTLA2_s8_n94_a3 = 1.0
# w_LB_DTLA2_s8_n95_a3 = 1.0
# w_LB_DTLA2_s8_n96_a3 = 1.0
# w_LB_DTLA2_s8_n97_a3 = 1.0
# w_LB_DTLA2_s8_n98_a3 = 1.0
# w_LB_DTLA2_s8_n99_a3 = 1.0
# w_LB_DTLA2_s9_n20_a3 = 1.0
# w_LB_DTLA2_s9_n21_a3 = 1.0
# w_LB_DTLA2_s9_n22_a3 = 1.0
# w_LB_DTLA2_s9_n23_a3 = 1.0
# w_LB_DTLA2_s9_n24_a3 = 1.0
# w_LB_DTLA2_s9_n25_a3 = 1.0
# w_LB_DTLA2_s9_n26_a3 = 1.0
# w_LB_DTLA2_s9_n27_a3 = 1.0
# w_LB_DTLA2_s9_n28_a3 = 1.0
# w_LB_DTLA2_s9_n29_a3 = 1.0
# w_LB_DTLA2_s9_n30_a3 = 1.0
# w_LB_DTLA2_s9_n31_a3 = 1.0
# w_LB_DTLA2_s9_n32_a3 = 1.0
# w_LB_DTLA2_s9_n33_a3 = 1.0
# w_LB_DTLA2_s9_n34_a3 = 1.0
# w_LB_DTLA2_s9_n35_a3 = 1.0
# w_LB_DTLA2_s9_n36_a3 = 1.0
# w_LB_DTLA2_s9_n37_a3 = 1.0
# w_LB_DTLA2_s9_n38_a3 = 1.0
# w_LB_DTLA2_s9_n39_a3 = 1.0
# w_LB_DTLA2_s9_n40_a3 = 1.0
# w_LB_DTLA2_s9_n41_a3 = 1.0
# w_LB_DTLA2_s9_n42_a3 = 1.0
# w_LB_DTLA2_s9_n43_a3 = 1.0
# w_LB_DTLA2_s9_n44_a3 = 1.0
# w_LB_DTLA2_s9_n45_a3 = 1.0
# w_LB_DTLA2_s9_n46_a3 = 1.0
# w_LB_DTLA2_s9_n47_a3 = 1.0
# w_LB_DTLA2_s9_n48_a3 = 1.0
# w_LB_DTLA2_s9_n49_a3 = 1.0
# w_LB_DTLA2_s9_n50_a3 = 1.0
# w_LB_DTLA2_s9_n51_a3 = 1.0
# w_LB_DTLA2_s9_n52_a3 = 1.0
# w_LB_DTLA2_s9_n53_a3 = 1.0
# w_LB_DTLA2_s9_n54_a3 = 1.0
# w_LB_DTLA2_s9_n55_a3 = 1.0
# w_LB_DTLA2_s9_n56_a3 = 1.0
# w_LB_DTLA2_s9_n57_a3 = 1.0
# w_LB_DTLA2_s9_n58_a3 = 1.0
# w_LB_DTLA2_s9_n59_a3 = 1.0
# w_LB_DTLA2_s9_n60_a3 = 1.0
# w_LB_DTLA2_s9_n61_a3 = 1.0
# w_LB_DTLA2_s9_n62_a3 = 1.0
# w_LB_DTLA2_s9_n63_a3 = 1.0
# w_LB_DTLA2_s9_n64_a3 = 1.0
# w_LB_DTLA2_s9_n65_a3 = 1.0
# w_LB_DTLA2_s9_n66_a3 = 1.0
# w_LB_DTLA2_s9_n67_a3 = 1.0
# w_LB_DTLA2_s9_n68_a3 = 1.0
# w_LB_DTLA2_s9_n69_a3 = 1.0
# w_LB_DTLA2_s9_n70_a3 = 1.0
# w_LB_DTLA2_s9_n71_a3 = 1.0
# w_LB_DTLA2_s9_n72_a3 = 1.0
# w_LB_DTLA2_s9_n73_a3 = 1.0
# w_LB_DTLA2_s9_n74_a3 = 1.0
# w_LB_DTLA2_s9_n75_a3 = 1.0
# w_LB_DTLA2_s9_n76_a3 = 1.0
# w_LB_DTLA2_s9_n77_a3 = 1.0
# w_LB_DTLA2_s9_n78_a3 = 1.0
# w_LB_DTLA2_s9_n79_a3 = 1.0
# w_LB_DTLA2_s9_n80_a3 = 1.0
# w_LB_DTLA2_s9_n81_a3 = 1.0
# w_LB_DTLA2_s9_n82_a3 = 1.0
# w_LB_DTLA2_s9_n83_a3 = 1.0
# w_LB_DTLA2_s9_n84_a3 = 1.0
# w_LB_DTLA2_s9_n85_a3 = 1.0
# w_LB_DTLA2_s9_n86_a3 = 1.0
# w_LB_DTLA2_s9_n87_a3 = 1.0
# w_LB_DTLA2_s9_n88_a3 = 1.0
# w_LB_DTLA2_s9_n89_a3 = 1.0
# w_LB_DTLA2_s9_n90_a3 = 1.0
# w_LB_DTLA2_s9_n91_a3 = 1.0
# w_LB_DTLA2_s9_n92_a3 = 1.0
# w_LB_DTLA2_s9_n93_a3 = 1.0
# w_LB_DTLA2_s9_n94_a3 = 1.0
# w_LB_DTLA2_s9_n95_a3 = 1.0
# w_LB_DTLA2_s9_n96_a3 = 1.0
# w_LB_DTLA2_s9_n97_a3 = 1.0
# w_LB_DTLA2_s9_n98_a3 = 1.0
# w_LB_DTLA2_s9_n99_a3 = 1.0
# wd_HB_DTLA1_n36_a0 = 1.0
# wd_HB_DTLA1_n37_a0 = 1.0
# wd_HB_DTLA1_n38_a0 = 1.0
# wd_HB_DTLA1_n39_a0 = 1.0
# wd_HB_DTLA1_n40_a0 = 1.0
# wd_HB_DTLA1_n41_a0 = 1.0
# wd_HB_DTLA1_n42_a0 = 1.0
# wd_HB_DTLA1_n43_a0 = 1.0
# wd_HB_DTLA1_n44_a0 = 1.0
# wd_HB_DTLA1_n45_a0 = 1.0
# wd_HB_DTLA1_n46_a0 = 1.0
# wd_HB_DTLA1_n47_a0 = 1.0
# wd_HB_DTLA1_n48_a0 = 1.0
# wd_HB_DTLA1_n49_a0 = 1.0
# wd_HB_DTLA1_n50_a0 = 1.0
# wd_HB_DTLA1_n51_a0 = 1.0
# wd_HB_DTLA1_n52_a0 = 1.0
# wd_HB_DTLA1_n53_a0 = 1.0
# wd_HB_DTLA1_n54_a0 = 1.0
# wd_HB_DTLA1_n55_a0 = 1.0
# wd_HB_DTLA1_n56_a0 = 1.0
# wd_HB_DTLA1_n57_a0 = 1.0
# wd_HB_DTLA1_n58_a0 = 1.0
# wd_HB_DTLA1_n59_a0 = 1.0
# wd_HB_DTLA1_n60_a0 = 1.0
# wd_HB_DTLA1_n61_a0 = 1.0
# wd_HB_DTLA1_n62_a0 = 1.0
# wd_HB_DTLA1_n63_a0 = 1.0
# wd_HB_DTLA1_n64_a0 = 1.0
# wd_HB_DTLA1_n65_a0 = 1.0
# wd_HB_DTLA1_n66_a0 = 1.0
# wd_HB_DTLA1_n67_a0 = 1.0
# wd_HB_DTLA1_n68_a0 = 1.0
# wd_HB_DTLA1_n69_a0 = 1.0
# wd_HB_DTLA1_n70_a0 = 1.0
# wd_HB_DTLA1_n71_a0 = 1.0
# wd_HB_DTLA1_n72_a0 = 1.0
# wd_HB_DTLA1_n73_a0 = 1.0
# wd_HB_DTLA1_n74_a0 = 1.0
# wd_HB_DTLA1_n75_a0 = 1.0
# wd_HB_DTLA1_n76_a0 = 1.0
# wd_HB_DTLA1_n77_a0 = 1.0
# wd_HB_DTLA1_n78_a0 = 1.0
# wd_HB_DTLA1_n79_a0 = 1.0
# wd_HB_DTLA1_n80_a0 = 1.0
# wd_HB_DTLA1_n81_a0 = 1.0
# wd_HB_DTLA1_n82_a0 = 1.0
# wd_HB_DTLA1_n83_a0 = 1.0
# wd_HB_DTLA1_n84_a0 = 1.0
# wd_HB_DTLA1_n85_a0 = 1.0
# wd_HB_DTLA1_n86_a0 = 1.0
# wd_HB_DTLA1_n87_a0 = 1.0
# wd_HB_DTLA1_n88_a0 = 1.0
# wd_HB_DTLA1_n89_a0 = 1.0
# wd_HB_DTLA1_n90_a0 = 1.0
# wd_HB_DTLA1_n91_a0 = 1.0
# wd_HB_DTLA1_n92_a0 = 1.0
# wd_HB_DTLA1_n93_a0 = 1.0
# wd_HB_DTLA1_n94_a0 = 1.0
# wd_HB_DTLA1_n95_a0 = 1.0
# wd_HB_DTLA1_n96_a0 = 1.0
# wd_HB_DTLA1_n97_a0 = 1.0
# wd_HB_DTLA1_n98_a0 = 1.0
# wd_HB_DTLA1_n99_a0 = 1.0
# wd_LB_DTLA2_n27_a3 = 1.0
# wd_LB_DTLA2_n28_a3 = 1.0
# wd_LB_DTLA2_n29_a3 = 1.0
# wd_LB_DTLA2_n30_a3 = 1.0
# wd_LB_DTLA2_n31_a3 = 1.0
# wd_LB_DTLA2_n32_a3 = 1.0
# wd_LB_DTLA2_n33_a3 = 1.0
# wd_LB_DTLA2_n34_a3 = 1.0
# wd_LB_DTLA2_n35_a3 = 1.0
# wd_LB_DTLA2_n36_a3 = 1.0
# wd_LB_DTLA2_n37_a3 = 1.0
# wd_LB_DTLA2_n38_a3 = 1.0
# wd_LB_DTLA2_n39_a3 = 1.0
# wd_LB_DTLA2_n40_a3 = 1.0
# wd_LB_DTLA2_n41_a3 = 1.0
# wd_LB_DTLA2_n42_a3 = 1.0
# wd_LB_DTLA2_n43_a3 = 1.0
# wd_LB_DTLA2_n44_a3 = 1.0
# wd_LB_DTLA2_n45_a3 = 1.0
# wd_LB_DTLA2_n46_a3 = 1.0
# wd_LB_DTLA2_n47_a3 = 1.0
# wd_LB_DTLA2_n48_a3 = 1.0
# wd_LB_DTLA2_n49_a3 = 1.0
# wd_LB_DTLA2_n50_a3 = 1.0
# wd_LB_DTLA2_n51_a3 = 1.0
# wd_LB_DTLA2_n52_a3 = 1.0
# wd_LB_DTLA2_n53_a3 = 1.0
# wd_LB_DTLA2_n54_a3 = 1.0
# wd_LB_DTLA2_n55_a3 = 1.0
# wd_LB_DTLA2_n56_a3 = 1.0
# wd_LB_DTLA2_n57_a3 = 1.0
# wd_LB_DTLA2_n58_a3 = 1.0
# wd_LB_DTLA2_n59_a3 = 1.0
# wd_LB_DTLA2_n60_a3 = 1.0
# wd_LB_DTLA2_n61_a3 = 1.0
# wd_LB_DTLA2_n62_a3 = 1.0
# wd_LB_DTLA2_n63_a3 = 1.0
# wd_LB_DTLA2_n64_a3 = 1.0
# wd_LB_DTLA2_n65_a3 = 1.0
# wd_LB_DTLA2_n66_a3 = 1.0
# wd_LB_DTLA2_n67_a3 = 1.0
# wd_LB_DTLA2_n68_a3 = 1.0
# wd_LB_DTLA2_n69_a3 = 1.0
# wd_LB_DTLA2_n70_a3 = 1.0
# wd_LB_DTLA2_n71_a3 = 1.0
# wd_LB_DTLA2_n72_a3 = 1.0
# wd_LB_DTLA2_n73_a3 = 1.0
# wd_LB_DTLA2_n74_a3 = 1.0
# wd_LB_DTLA2_n75_a3 = 1.0
# wd_LB_DTLA2_n76_a3 = 1.0
# wd_LB_DTLA2_n77_a3 = 1.0
# wd_LB_DTLA2_n78_a3 = 1.0
# wd_LB_DTLA2_n79_a3 = 1.0
# wd_LB_DTLA2_n80_a3 = 1.0
# wd_LB_DTLA2_n81_a3 = 1.0
# wd_LB_DTLA2_n82_a3 = 1.0
# wd_LB_DTLA2_n83_a3 = 1.0
# wd_LB_DTLA2_n84_a3 = 1.0
# wd_LB_DTLA2_n85_a3 = 1.0
# wd_LB_DTLA2_n86_a3 = 1.0
# wd_LB_DTLA2_n87_a3 = 1.0
# wd_LB_DTLA2_n88_a3 = 1.0
# wd_LB_DTLA2_n89_a3 = 1.0
# wd_LB_DTLA2_n90_a3 = 1.0
# wd_LB_DTLA2_n91_a3 = 1.0
# wd_LB_DTLA2_n92_a3 = 1.0
# wd_LB_DTLA2_n93_a3 = 1.0
# wd_LB_DTLA2_n94_a3 = 1.0
# wd_LB_DTLA2_n95_a3 = 1.0
# wd_LB_DTLA2_n96_a3 = 1.0
# wd_LB_DTLA2_n97_a3 = 1.0
# wd_LB_DTLA2_n98_a3 = 1.0
# wd_LB_DTLA2_n99_a3 = 1.0
# wo_DTLA2_HB_n99_a3 = 1.0
# wo_HB_DTLA1_n19_a0 = 1.0
# wo_HB_DTLA1_n20_a0 = 1.0
# wo_HB_DTLA1_n21_a0 = 1.0
# wo_HB_DTLA1_n22_a0 = 1.0
# wo_HB_DTLA1_n23_a0 = 1.0
# wo_HB_DTLA1_n24_a0 = 1.0
# wo_HB_DTLA1_n25_a0 = 1.0
# wo_HB_DTLA1_n26_a0 = 1.0
# wo_HB_DTLA1_n27_a0 = 1.0
# wo_HB_DTLA1_n28_a0 = 1.0
# wo_HB_DTLA1_n29_a0 = 1.0
# wo_HB_DTLA1_n30_a0 = 1.0
# wo_HB_DTLA1_n31_a0 = 1.0
# wo_HB_DTLA1_n32_a0 = 1.0
# wo_HB_DTLA1_n33_a0 = 1.0
# wo_HB_DTLA1_n34_a0 = 1.0
# wo_HB_DTLA1_n35_a0 = 1.0
# wo_HB_DTLA1_n36_a0 = 1.0
# wo_HB_DTLA1_n37_a0 = 1.0
# wo_HB_DTLA1_n38_a0 = 1.0
# wo_HB_DTLA1_n39_a0 = 1.0
# wo_HB_DTLA1_n40_a0 = 1.0
# wo_HB_DTLA1_n41_a0 = 1.0
# wo_HB_DTLA1_n42_a0 = 1.0
# wo_HB_DTLA1_n43_a0 = 1.0
# wo_HB_DTLA1_n44_a0 = 1.0
# wo_HB_DTLA1_n45_a0 = 1.0
# wo_HB_DTLA1_n46_a0 = 1.0
# wo_HB_DTLA1_n47_a0 = 1.0
# wo_HB_DTLA1_n48_a0 = 1.0
# wo_HB_DTLA1_n49_a0 = 1.0
# wo_HB_DTLA1_n50_a0 = 1.0
# wo_HB_DTLA1_n51_a0 = 1.0
# wo_HB_DTLA1_n52_a0 = 1.0
# wo_HB_DTLA1_n53_a0 = 1.0
# wo_HB_DTLA1_n54_a0 = 1.0
# wo_HB_DTLA1_n55_a0 = 1.0
# wo_HB_DTLA1_n56_a0 = 1.0
# wo_HB_DTLA1_n57_a0 = 1.0
# wo_HB_DTLA1_n58_a0 = 1.0
# wo_HB_DTLA1_n59_a0 = 1.0
# wo_HB_DTLA1_n60_a0 = 1.0
# wo_HB_DTLA1_n61_a0 = 1.0
# wo_HB_DTLA1_n62_a0 = 1.0
# wo_HB_DTLA1_n63_a0 = 1.0
# wo_HB_DTLA1_n64_a0 = 1.0
# wo_HB_DTLA1_n65_a0 = 1.0
# wo_HB_DTLA1_n66_a0 = 1.0
# wo_HB_DTLA1_n67_a0 = 1.0
# wo_HB_DTLA1_n68_a0 = 1.0
# wo_HB_DTLA1_n69_a0 = 1.0
# wo_HB_DTLA1_n70_a0 = 1.0
# wo_HB_DTLA1_n71_a0 = 1.0
# wo_HB_DTLA1_n72_a0 = 1.0
# wo_HB_DTLA1_n73_a0 = 1.0
# wo_HB_DTLA1_n74_a0 = 1.0
# wo_HB_DTLA1_n75_a0 = 1.0
# wo_HB_DTLA1_n76_a0 = 1.0
# wo_HB_DTLA1_n77_a0 = 1.0
# wo_HB_DTLA1_n78_a0 = 1.0
# wo_HB_DTLA1_n79_a0 = 1.0
# wo_HB_DTLA1_n80_a0 = 1.0
# wo_HB_DTLA1_n81_a0 = 1.0
# wo_HB_DTLA1_n82_a0 = 1.0
# wo_HB_DTLA1_n83_a0 = 1.0
# wo_HB_DTLA1_n84_a0 = 1.0
# wo_HB_DTLA1_n85_a0 = 1.0
# wo_HB_DTLA1_n86_a0 = 1.0
# wo_HB_DTLA1_n87_a0 = 1.0
# wo_HB_DTLA1_n88_a0 = 1.0
# wo_HB_DTLA1_n89_a0 = 1.0
# wo_HB_DTLA1_n90_a0 = 1.0
# wo_HB_DTLA1_n91_a0 = 1.0
# wo_HB_DTLA1_n92_a0 = 1.0
# wo_HB_DTLA1_n93_a0 = 1.0
# wo_HB_DTLA1_n94_a0 = 1.0
# wo_HB_DTLA1_n95_a0 = 1.0
# wo_HB_DTLA1_n96_a0 = 1.0
# wo_HB_DTLA1_n97_a0 = 1.0
# wo_HB_DTLA1_n98_a0 = 1.0
# wo_HB_DTLA1_n99_a0 = 1.0
# wo_HB_DTLA2_n99_a2 = 1.0
# wo_LB_DTLA1_n99_a1 = 1.0
# wo_LB_DTLA2_n10_a3 = 1.0
# wo_LB_DTLA2_n11_a3 = 1.0
# wo_LB_DTLA2_n12_a3 = 1.0
# wo_LB_DTLA2_n13_a3 = 1.0
# wo_LB_DTLA2_n14_a3 = 1.0
# wo_LB_DTLA2_n15_a3 = 1.0
# wo_LB_DTLA2_n16_a3 = 1.0
# wo_LB_DTLA2_n17_a3 = 1.0
# wo_LB_DTLA2_n18_a3 = 1.0
# wo_LB_DTLA2_n19_a3 = 1.0
# wo_LB_DTLA2_n20_a3 = 1.0
# wo_LB_DTLA2_n21_a3 = 1.0
# wo_LB_DTLA2_n22_a3 = 1.0
# wo_LB_DTLA2_n23_a3 = 1.0
# wo_LB_DTLA2_n24_a3 = 1.0
# wo_LB_DTLA2_n25_a3 = 1.0
# wo_LB_DTLA2_n26_a3 = 1.0
# wo_LB_DTLA2_n27_a3 = 1.0
# wo_LB_DTLA2_n28_a3 = 1.0
# wo_LB_DTLA2_n29_a3 = 1.0
# wo_LB_DTLA2_n30_a3 = 1.0
# wo_LB_DTLA2_n31_a3 = 1.0
# wo_LB_DTLA2_n32_a3 = 1.0
# wo_LB_DTLA2_n33_a3 = 1.0
# wo_LB_DTLA2_n34_a3 = 1.0
# wo_LB_DTLA2_n35_a3 = 1.0
# wo_LB_DTLA2_n36_a3 = 1.0
# wo_LB_DTLA2_n37_a3 = 1.0
# wo_LB_DTLA2_n38_a3 = 1.0
# wo_LB_DTLA2_n39_a3 = 1.0
# wo_LB_DTLA2_n40_a3 = 1.0
# wo_LB_DTLA2_n41_a3 = 1.0
# wo_LB_DTLA2_n42_a3 = 1.0
# wo_LB_DTLA2_n43_a3 = 1.0
# wo_LB_DTLA2_n44_a3 = 1.0
# wo_LB_DTLA2_n45_a3 = 1.0
# wo_LB_DTLA2_n46_a3 = 1.0
# wo_LB_DTLA2_n47_a3 = 1.0
# wo_LB_DTLA2_n48_a3 = 1.0
# wo_LB_DTLA2_n49_a3 = 1.0
# wo_LB_DTLA2_n50_a3 = 1.0
# wo_LB_DTLA2_n51_a3 = 1.0
# wo_LB_DTLA2_n52_a3 = 1.0
# wo_LB_DTLA2_n53_a3 = 1.0
# wo_LB_DTLA2_n54_a3 = 1.0
# wo_LB_DTLA2_n55_a3 = 1.0
# wo_LB_DTLA2_n56_a3 = 1.0
# wo_LB_DTLA2_n57_a3 = 1.0
# wo_LB_DTLA2_n58_a3 = 1.0
# wo_LB_DTLA2_n59_a3 = 1.0
# wo_LB_DTLA2_n60_a3 = 1.0
# wo_LB_DTLA2_n61_a3 = 1.0
# wo_LB_DTLA2_n62_a3 = 1.0
# wo_LB_DTLA2_n63_a3 = 1.0
# wo_LB_DTLA2_n64_a3 = 1.0
# wo_LB_DTLA2_n65_a3 = 1.0
# wo_LB_DTLA2_n66_a3 = 1.0
# wo_LB_DTLA2_n67_a3 = 1.0
# wo_LB_DTLA2_n68_a3 = 1.0
# wo_LB_DTLA2_n69_a3 = 1.0
# wo_LB_DTLA2_n70_a3 = 1.0
# wo_LB_DTLA2_n71_a3 = 1.0
# wo_LB_DTLA2_n72_a3 = 1.0
# wo_LB_DTLA2_n73_a3 = 1.0
# wo_LB_DTLA2_n74_a3 = 1.0
# wo_LB_DTLA2_n75_a3 = 1.0
# wo_LB_DTLA2_n76_a3 = 1.0
# wo_LB_DTLA2_n77_a3 = 1.0
# wo_LB_DTLA2_n78_a3 = 1.0
# wo_LB_DTLA2_n79_a3 = 1.0
# wo_LB_DTLA2_n80_a3 = 1.0
# wo_LB_DTLA2_n81_a3 = 1.0
# wo_LB_DTLA2_n82_a3 = 1.0
# wo_LB_DTLA2_n83_a3 = 1.0
# wo_LB_DTLA2_n84_a3 = 1.0
# wo_LB_DTLA2_n85_a3 = 1.0
# wo_LB_DTLA2_n86_a3 = 1.0
# wo_LB_DTLA2_n87_a3 = 1.0
# wo_LB_DTLA2_n88_a3 = 1.0
# wo_LB_DTLA2_n89_a3 = 1.0
# wo_LB_DTLA2_n90_a3 = 1.0
# wo_LB_DTLA2_n91_a3 = 1.0
# wo_LB_DTLA2_n92_a3 = 1.0
# wo_LB_DTLA2_n93_a3 = 1.0
# wo_LB_DTLA2_n94_a3 = 1.0
# wo_LB_DTLA2_n95_a3 = 1.0
# wo_LB_DTLA2_n96_a3 = 1.0
# wo_LB_DTLA2_n97_a3 = 1.0
# wo_LB_DTLA2_n98_a3 = 1.0
# wo_LB_DTLA2_n99_a3 = 1.0
